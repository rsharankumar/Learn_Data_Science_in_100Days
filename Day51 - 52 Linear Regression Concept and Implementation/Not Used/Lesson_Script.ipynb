# %%
import pandas as pd

# %%
housing_data = pd.read_csv('Data/Melbourne_housing_FULL.csv')
housing_data.head(5)
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
#    YearBuilt         CouncilArea Lattitude  Longtitude             Regionname  \
# 0        NaN  Yarra City Council  -37.8014    144.9958  Northern Metropolitan
# 1        NaN  Yarra City Council  -37.7996    144.9984  Northern Metropolitan
# 2     1900.0  Yarra City Council  -37.8079    144.9934  Northern Metropolitan
# 3        NaN  Yarra City Council  -37.8114    145.0116  Northern Metropolitan
# 4     1900.0  Yarra City Council  -37.8093    144.9944  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# 3        4019.0
# 4        4019.0
#
# [5 rows x 21 columns]

# %%
# What is the data type
housing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34857 entries, 0 to 34856
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         34857 non-null  object
#  1   Address        34857 non-null  object
#  2   Rooms          34857 non-null  int64
#  3   Type           34857 non-null  object
#  4   Price          27247 non-null  float64
#  5   Method         34857 non-null  object
#  6   SellerG        34857 non-null  object
#  7   Date           34857 non-null  object
#  8   Distance       34856 non-null  float64
#  9   Postcode       34856 non-null  float64
#  10  Bedroom2       26640 non-null  float64
#  11  Bathroom       26631 non-null  float64
#  12  Car            26129 non-null  float64
#  13  Landsize       23047 non-null  float64
#  14  BuildingArea   13742 non-null  float64
#  15  YearBuilt      15551 non-null  float64
#  16  CouncilArea    34854 non-null  object
#  17  Lattitude      26881 non-null  float64
#  18  Longtitude     26881 non-null  float64
#  19  Regionname     34854 non-null  object
#  20  Propertycount  34854 non-null  float64
# dtypes: float64(12), int64(1), object(8)
# memory usage: 5.6+ MB

# %%
# Get tp know the numerical data better
housing_data.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  34857.000000  2.724700e+04  34856.000000  34856.000000  26640.000000
# mean       3.031012  1.050173e+06     11.184929   3116.062859      3.084647
# std        0.969933  6.414671e+05      6.788892    109.023903      0.980690
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.350000e+05      6.400000   3051.000000      2.000000
# 50%        3.000000  8.700000e+05     10.300000   3103.000000      3.000000
# 75%        4.000000  1.295000e+06     14.000000   3156.000000      4.000000
# max       16.000000  1.120000e+07     48.100000   3978.000000     30.000000
#
#            Bathroom           Car       Landsize  BuildingArea     YearBuilt  \
# count  26631.000000  26129.000000   23047.000000   13742.00000  15551.000000
# mean       1.624798      1.728845     593.598993     160.25640   1965.289885
# std        0.724212      1.010771    3398.841946     401.26706     37.328178
# min        0.000000      0.000000       0.000000       0.00000   1196.000000
# 25%        1.000000      1.000000     224.000000     102.00000   1940.000000
# 50%        2.000000      2.000000     521.000000     136.00000   1970.000000
# 75%        2.000000      2.000000     670.000000     188.00000   2000.000000
# max       12.000000     26.000000  433014.000000   44515.00000   2106.000000
#
#           Lattitude    Longtitude  Propertycount
# count  26881.000000  26881.000000   34854.000000
# mean     -37.810634    145.001851    7572.888306
# std        0.090279      0.120169    4428.090313
# min      -38.190430    144.423790      83.000000
# 25%      -37.862950    144.933500    4385.000000
# 50%      -37.807600    145.007800    6763.000000
# 75%      -37.754100    145.071900   10412.000000
# max      -37.390200    145.526350   21650.000000

# %%
# Find the number of missing data
housing_data.isna().sum()/len(housing_data)*100
# Out:
# Suburb            0.000000
# Address           0.000000
# Rooms             0.000000
# Type              0.000000
# Price            21.832057
# Method            0.000000
# SellerG           0.000000
# Date              0.000000
# Distance          0.002869
# Postcode          0.002869
# Bedroom2         23.573457
# Bathroom         23.599277
# Car              25.039447
# Landsize         33.881286
# BuildingArea     60.576068
# YearBuilt        55.386293
# CouncilArea       0.008607
# Lattitude        22.882061
# Longtitude       22.882061
# Regionname        0.008607
# Propertycount     0.008607
# dtype: float64

# %%
new_housing_data = housing_data

# %%
new_housing_data['Price'].fillna(new_housing_data['Price'].mean(), inplace=True)

# %%
new_housing_data.isna().sum()/len(housing_data)*100
# Out:
# Suburb            0.000000
# Address           0.000000
# Rooms             0.000000
# Type              0.000000
# Price             0.000000
# Method            0.000000
# SellerG           0.000000
# Date              0.000000
# Distance          0.002869
# Postcode          0.002869
# Bedroom2         23.573457
# Bathroom         23.599277
# Car              25.039447
# Landsize         33.881286
# BuildingArea     60.576068
# YearBuilt        55.386293
# CouncilArea       0.008607
# Lattitude        22.882061
# Longtitude       22.882061
# Regionname        0.008607
# Propertycount     0.008607
# dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(16,7))
sns.distplot(housing_data.loc[housing_data["Price"] < 1000000, ['Price']], kde = False, hist_kws = dict(edgecolor = "k"))
# Out:
# C:\Users\skumarravindran\AppData\Local\Continuum\anaconda3\envs\DS100\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt

housing_data['Date'] = pd.to_datetime(housing_data['Date'])

std = housing_data[(housing_data["Type"]=="h") & (housing_data["Rooms"]<=4) & (housing_data["Price"] < 1000000)].sort_values("Date", ascending=True).groupby("Date").std()
count = housing_data[(housing_data["Type"]=="h") & (housing_data["Rooms"]<=4) & (housing_data["Price"] < 1000000)].sort_values("Date", ascending=True).groupby("Date").count()
mean = housing_data[(housing_data["Type"]=="h") & (housing_data["Rooms"]<=4) & (housing_data["Price"] < 1000000)].sort_values("Date", ascending=True).groupby("Date").mean()

mean["Price"].plot(yerr=std["Price"],ylim=(400000,1500000), figsize = (15, 5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
gp_df = housing_data.groupby(['Regionname', 'Type'])['Price'].mean()
print(gp_df)
# Out:
# Regionname                  Type
# Eastern Metropolitan        h       1.159429e+06
#                             t       9.593282e+05
#                             u       7.791411e+05
# Eastern Victoria            h       8.088998e+05
#                             t       8.961040e+05
#                             u       6.409067e+05
# Northern Metropolitan       h       9.894457e+05
#                             t       7.807428e+05
#                             u       6.512898e+05
# Northern Victoria           h       7.000599e+05
#                             t       6.480000e+05
#                             u       5.530000e+05
# South-Eastern Metropolitan  h       9.617943e+05
#                             t       9.095537e+05
#                             u       6.488721e+05
# Southern Metropolitan       h       1.591019e+06
#                             t       1.183943e+06
#                             u       7.674882e+05
# Western Metropolitan        h       9.321050e+05
#                             t       7.731458e+05
#                             u       5.839877e+05
# Western Victoria            h       5.390579e+05
#                             u       2.850000e+05
# Name: Price, dtype: float64

# %%
sns.lmplot("Distance","Price",housing_data[(housing_data["Rooms"]<=4) & 
                                        (housing_data["Price"]< 1000000)
                                       ].dropna(),hue="Rooms", size=10)
# Out:
# C:\Users\skumarravindran\AppData\Local\Continuum\anaconda3\envs\DS100\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\skumarravindran\AppData\Local\Continuum\anaconda3\envs\DS100\lib\site-packages\seaborn\regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Practice Questions: <br>
# What is the average price of property by postcode?<br>
# Number of properties by regions?<br>
# Average property price by suburbs?<br>
# What is the most popular suburb?<br>
# What is the relationship between the number of rooms and property price?<br>

# %% [markdown]
# #### Predicting using Linear Regression

# %%
# Removing cases where there was no price
housing_data_filtered = housing_data[housing_data.Price.notnull()]
housing_data_filtered.head()
# Out:
#        Suburb             Address  Rooms Type         Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h  1.050173e+06     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1.480000e+06      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1.035000e+06      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u  1.050173e+06     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1.465000e+06     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0 2016-03-09       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1 2016-03-12       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2 2016-04-02       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3 2016-04-02       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4 2017-04-03       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
#    YearBuilt         CouncilArea Lattitude  Longtitude             Regionname  \
# 0        NaN  Yarra City Council  -37.8014    144.9958  Northern Metropolitan
# 1        NaN  Yarra City Council  -37.7996    144.9984  Northern Metropolitan
# 2     1900.0  Yarra City Council  -37.8079    144.9934  Northern Metropolitan
# 3        NaN  Yarra City Council  -37.8114    145.0116  Northern Metropolitan
# 4     1900.0  Yarra City Council  -37.8093    144.9944  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# 3        4019.0
# 4        4019.0
#
# [5 rows x 21 columns]

# %%
from pandas.api.types import is_string_dtype
#Tranform categorical data into numerical data for training purpose
for col, col_data in housing_data_filtered.items():
    if is_string_dtype(col_data):
        housing_data_filtered[col] = housing_data_filtered[col].astype('category').cat.as_ordered().cat.codes

# %%
housing_data_filtered.head()
# Out:
#    Suburb  Address  Rooms  Type         Price  Method  SellerG       Date  \
# 0       0    29458      2     0  1.050173e+06       6      155 2016-03-09
# 1       0    32512      2     0  1.480000e+06       2       33 2016-03-12
# 2       0    15389      2     0  1.035000e+06       2       33 2016-04-02
# 3       0     9768      3     2  1.050173e+06       7      296 2016-04-02
# 4       0    25128      3     0  1.465000e+06       5       33 2017-04-03
#
#    Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  YearBuilt  \
# 0       2.5    3067.0  ...       1.0  1.0     126.0           NaN        NaN
# 1       2.5    3067.0  ...       1.0  1.0     202.0           NaN        NaN
# 2       2.5    3067.0  ...       1.0  0.0     156.0          79.0     1900.0
# 3       2.5    3067.0  ...       2.0  1.0       0.0           NaN        NaN
# 4       2.5    3067.0  ...       2.0  0.0     134.0         150.0     1900.0
#
#    CouncilArea  Lattitude  Longtitude  Regionname  Propertycount
# 0           31   -37.8014    144.9958           2         4019.0
# 1           31   -37.7996    144.9984           2         4019.0
# 2           31   -37.8079    144.9934           2         4019.0
# 3           31   -37.8114    145.0116           2         4019.0
# 4           31   -37.8093    144.9944           2         4019.0
#
# [5 rows x 21 columns]

# %%
corrmat = housing_data_filtered.corr()
corrmat.head(21)
# Out:
#                  Suburb   Address     Rooms      Type     Price    Method  \
# Suburb         1.000000  0.015609 -0.064271  0.022750 -0.121037  0.001405
# Address        0.015609  1.000000  0.022116 -0.070503  0.034200  0.006326
# Rooms         -0.064271  0.022116  1.000000 -0.550992  0.404908 -0.029778
# Type           0.022750 -0.070503 -0.550992  1.000000 -0.329911  0.043113
# Price         -0.121037  0.034200  0.404908 -0.329911  1.000000 -0.009431
# Method         0.001405  0.006326 -0.029778  0.043113 -0.009431  1.000000
# SellerG        0.034903 -0.002137 -0.040063  0.030186 -0.041143  0.002896
# Distance      -0.007840 -0.026620  0.271511 -0.235798 -0.186849 -0.041120
# Postcode      -0.014178 -0.000163  0.085890 -0.030485  0.040512 -0.009798
# Bedroom2      -0.055460  0.016586  0.946755 -0.505942  0.368067 -0.017121
# Bathroom      -0.054201  0.005210  0.611826 -0.224187  0.365058  0.003203
# Car           -0.031082 -0.002473  0.393878 -0.264314  0.174743 -0.010660
# Landsize       0.000708  0.007260  0.037402 -0.022672  0.031958  0.008753
# BuildingArea  -0.011000  0.015120  0.156229 -0.087115  0.098883 -0.006353
# YearBuilt      0.028735 -0.059246 -0.012749  0.281698 -0.288049 -0.006498
# CouncilArea    0.112177  0.013175 -0.120861  0.069836 -0.094509  0.001522
# Lattitude      0.128608 -0.011085  0.004872 -0.085209 -0.191110 -0.015751
# Longtitude    -0.149092  0.000547  0.103235 -0.009198  0.173248 -0.018645
# Regionname    -0.018914  0.009380 -0.038651  0.058296  0.067626  0.016915
# Propertycount  0.149115  0.007403 -0.071677  0.074679 -0.052935 -0.028175
#
#                 SellerG  Distance  Postcode  Bedroom2  Bathroom       Car  \
# Suburb         0.034903 -0.007840 -0.014178 -0.055460 -0.054201 -0.031082
# Address       -0.002137 -0.026620 -0.000163  0.016586  0.005210 -0.002473
# Rooms         -0.040063  0.271511  0.085890  0.946755  0.611826  0.393878
# Type           0.030186 -0.235798 -0.030485 -0.505942 -0.224187 -0.264314
# Price         -0.041143 -0.186849  0.040512  0.368067  0.365058  0.174743
# Method         0.002896 -0.041120 -0.009798 -0.017121  0.003203 -0.010660
# SellerG        1.000000 -0.025243 -0.005506 -0.037141 -0.030190  0.002421
# Distance      -0.025243  1.000000  0.481566  0.269524  0.126201  0.241835
# Postcode      -0.005506  0.481566  1.000000  0.089292  0.120080  0.067886
# Bedroom2      -0.037141  0.269524  0.089292  1.000000  0.614892  0.388491
# Bathroom      -0.030190  0.126201  0.120080  0.614892  1.000000  0.307518
# Car            0.002421  0.241835  0.067886  0.388491  0.307518  1.000000
# Landsize      -0.000636  0.060862  0.040664  0.037019  0.036333  0.037829
# BuildingArea  -0.000101  0.076301  0.042437  0.154157  0.147558  0.104373
# YearBuilt     -0.012125  0.323059  0.089805 -0.002022  0.167955  0.128702
# CouncilArea    0.040146 -0.122343  0.013252 -0.114298 -0.069062 -0.127012
# Lattitude      0.005844 -0.100417 -0.231027  0.003447 -0.059183 -0.009020
# Longtitude    -0.068638  0.200946  0.362895  0.106164  0.106531  0.047213
# Regionname     0.026275 -0.136102 -0.031745 -0.047550  0.009718  0.011351
# Propertycount  0.044486 -0.018140  0.017108 -0.053451 -0.032887 -0.009617
#
#                Landsize  BuildingArea  YearBuilt  CouncilArea  Lattitude  \
# Suburb         0.000708     -0.011000   0.028735     0.112177   0.128608
# Address        0.007260      0.015120  -0.059246     0.013175  -0.011085
# Rooms          0.037402      0.156229  -0.012749    -0.120861   0.004872
# Type          -0.022672     -0.087115   0.281698     0.069836  -0.085209
# Price          0.031958      0.098883  -0.288049    -0.094509  -0.191110
# Method         0.008753     -0.006353  -0.006498     0.001522  -0.015751
# SellerG       -0.000636     -0.000101  -0.012125     0.040146   0.005844
# Distance       0.060862      0.076301   0.323059    -0.122343  -0.100417
# Postcode       0.040664      0.042437   0.089805     0.013252  -0.231027
# Bedroom2       0.037019      0.154157  -0.002022    -0.114298   0.003447
# Bathroom       0.036333      0.147558   0.167955    -0.069062  -0.059183
# Car            0.037829      0.104373   0.128702    -0.127012  -0.009020
# Landsize       1.000000      0.354530   0.044474     0.002830   0.025318
# BuildingArea   0.354530      1.000000   0.067811    -0.031212   0.017155
# YearBuilt      0.044474      0.067811   1.000000    -0.029595   0.091592
# CouncilArea    0.002830     -0.031212  -0.029595     1.000000   0.084693
# Lattitude      0.025318      0.017155   0.091592     0.084693   1.000000
# Longtitude    -0.002582     -0.002143  -0.022175    -0.131714  -0.345589
# Regionname    -0.014342     -0.000757  -0.043509    -0.077030  -0.281039
# Propertycount -0.018195     -0.024523   0.022420     0.020691   0.011112
#
#                Longtitude  Regionname  Propertycount
# Suburb          -0.149092   -0.018914       0.149115
# Address          0.000547    0.009380       0.007403
# Rooms            0.103235   -0.038651      -0.071677
# Type            -0.009198    0.058296       0.074679
# Price            0.173248    0.067626      -0.052935
# Method          -0.018645    0.016915      -0.028175
# SellerG         -0.068638    0.026275       0.044486
# Distance         0.200946   -0.136102      -0.018140
# Postcode         0.362895   -0.031745       0.017108
# Bedroom2         0.106164   -0.047550      -0.053451
# Bathroom         0.106531    0.009718      -0.032887
# Car              0.047213    0.011351      -0.009617
# Landsize        -0.002582   -0.014342      -0.018195
# BuildingArea    -0.002143   -0.000757      -0.024523
# YearBuilt       -0.022175   -0.043509       0.022420
# CouncilArea     -0.131714   -0.077030       0.020691
# Lattitude       -0.345589   -0.281039       0.011112
# Longtitude       1.000000   -0.508331       0.016326
# Regionname      -0.508331    1.000000      -0.114134
# Propertycount    0.016326   -0.114134       1.000000

# %%
important_cols = ['Rooms', 'Type', 'Distance', 'Bedroom2', 'Bathroom', 'Car', 'YearBuilt', 'Price']
corrmat_v2 = housing_data_filtered[important_cols].corr()
corrmat_v2.head(8)
# Out:
#               Rooms      Type  Distance  Bedroom2  Bathroom       Car  \
# Rooms      1.000000 -0.550992  0.271511  0.946755  0.611826  0.393878
# Type      -0.550992  1.000000 -0.235798 -0.505942 -0.224187 -0.264314
# Distance   0.271511 -0.235798  1.000000  0.269524  0.126201  0.241835
# Bedroom2   0.946755 -0.505942  0.269524  1.000000  0.614892  0.388491
# Bathroom   0.611826 -0.224187  0.126201  0.614892  1.000000  0.307518
# Car        0.393878 -0.264314  0.241835  0.388491  0.307518  1.000000
# YearBuilt -0.012749  0.281698  0.323059 -0.002022  0.167955  0.128702
# Price      0.404908 -0.329911 -0.186849  0.368067  0.365058  0.174743
#
#            YearBuilt     Price
# Rooms      -0.012749  0.404908
# Type        0.281698 -0.329911
# Distance    0.323059 -0.186849
# Bedroom2   -0.002022  0.368067
# Bathroom    0.167955  0.365058
# Car         0.128702  0.174743
# YearBuilt   1.000000 -0.288049
# Price      -0.288049  1.000000

# %%
#Feature Selection
important_cols.remove('Bedroom2')
cols = important_cols
housing_data_filtered = housing_data_filtered[cols]
housing_data_filtered.head()
# Out:
#    Rooms  Type  Distance  Bathroom  Car  YearBuilt         Price
# 0      2     0       2.5       1.0  1.0        NaN  1.050173e+06
# 1      2     0       2.5       1.0  1.0        NaN  1.480000e+06
# 2      2     0       2.5       1.0  0.0     1900.0  1.035000e+06
# 3      3     2       2.5       2.0  1.0        NaN  1.050173e+06
# 4      3     0       2.5       2.0  0.0     1900.0  1.465000e+06

# %%
from sklearn.impute import SimpleImputer
#Replace null data cells with means value using Simple Imputer
y = housing_data_filtered.Price
cols.remove('Price')
X = SimpleImputer().fit_transform(housing_data_filtered[cols])

# %%
from sklearn.model_selection import train_test_split, cross_val_score
#Split the data into training and validation data sets
train_X, val_X, train_y, val_y = train_test_split(X, y, test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(train_X, train_y)
# Out:
# LinearRegression()

# %%
predict_y = model.predict(val_X)

# %%
#Plot the actual Price value against predicted Sale Price 
g = sns.jointplot(x= val_y, y= predict_y, kind='reg', xlim=(0,8500000), ylim=(0,8500000),
                  joint_kws={'line_kws':{'color':'darkorange'}})
g.set_axis_labels(xlabel='Actual Price', ylabel='Predicted Price')

# %%
predict_y_df = pd.DataFrame(predict_y)
compare = pd.concat([val_y.reset_index(drop=True), predict_y_df], axis=1)
compare.columns = ['Actual', 'Predicted']
compare['Actual'] = compare['Actual'].astype('int64')
compare['Predicted'] = compare['Predicted'].astype('int64')
compare.head()
# Out:
#     Actual  Predicted
# 0  2003000    1252491
# 1  1050173    1258034
# 2   821000     951214
# 3   408000     571762
# 4  1750000    1707998
