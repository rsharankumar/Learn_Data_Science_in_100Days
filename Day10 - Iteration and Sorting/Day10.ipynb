# %% [markdown]
# #### Topics Covered
# - Iteration
# - Sorting

# %%
#import pandas library and provide alias name as pd
import pandas as pd

trend_data = pd.read_csv('Data/SearchTrendData.csv')
trend_data.head(5)
# Out:
#          Week  eLearning  DataScience  MachineLearning  \
# 0  20/09/2015         32            9               11
# 1  27/09/2015         35           10               11
# 2   4/10/2015         38           10               12
# 3  11/10/2015         37            9               12
# 4  18/10/2015         38            9               12
#
#    ArtificialIntelligence  DeepLearning
# 0                      11             4
# 1                      11             4
# 2                      11             4
# 3                      10             4
# 4                      10             4

# %% [markdown]
# 1. Iteration

# %% [markdown]
# 1a. Iterates through each row in the data frame

# %%
for row_index,row in trend_data.iterrows():
   print(row_index,row)
# Out:
# 0 Week                      20/09/2015
# eLearning                         32
# DataScience                        9
# MachineLearning                   11
# ArtificialIntelligence            11
# DeepLearning                       4
# Name: 0, dtype: object
# 1 Week                      27/09/2015
# eLearning                         35
# DataScience                       10
# MachineLearning                   11
# ArtificialIntelligence            11
# DeepLearning                       4
# Name: 1, dtype: object
# 2 Week                      4/10/2015
# eLearning                        38
# DataScience                      10
# MachineLearning                  12
# ArtificialIntelligence           11
# DeepLearning                      4
# Name: 2, dtype: object
# 3 Week                      11/10/2015
# eLearning                         37
# DataScience                        9
# MachineLearning                   12
# ArtificialIntelligence            10
# DeepLearning                       4
# Name: 3, dtype: object
# 4 Week                      18/10/2015
# eLearning                         38
# DataScience                        9
# MachineLearning                   12
# ArtificialIntelligence            10
# DeepLearning                       4
# Name: 4, dtype: object
# 5 Week                      25/10/2015
# eLearning                         38
# DataScience                       10
# MachineLearning                   12
# ArtificialIntelligence            11
# DeepLearning                       4
# Name: 5, dtype: object
# 6 Week                      1/11/2015
# eLearning                        37
# DataScience                       9
# MachineLearning                  13
# ArtificialIntelligence           11
# DeepLearning                      3
# Name: 6, dtype: object
# 7 Week                      8/11/2015
# eLearning                        35
# DataScience                       8
# MachineLearning                  14
# ArtificialIntelligence           12
# DeepLearning                      5
# Name: 7, dtype: object
# 8 Week                      15/11/2015
# eLearning                         35
# DataScience                        9
# MachineLearning                   13
# ArtificialIntelligence            12
# DeepLearning                       4
# Name: 8, dtype: object
# 9 Week                      22/11/2015
# eLearning                         31
# DataScience                        8
# MachineLearning                   12
# ArtificialIntelligence            10
# DeepLearning                       4
# Name: 9, dtype: object
# 10 Week                      29/11/2015
# eLearning                         35
# DataScience                        9
# MachineLearning                   13
# ArtificialIntelligence            11
# DeepLearning                       4
# Name: 10, dtype: object
# 11 Week                      6/12/2015
# eLearning                        33
# DataScience                       9
# MachineLearning                  13
# ArtificialIntelligence           12
# DeepLearning                      5
# Name: 11, dtype: object
# 12 Week                      13/12/2015
# eLearning                         30
# DataScience                        9
# MachineLearning                   14
# ArtificialIntelligence            11
# DeepLearning                       5
# Name: 12, dtype: object
# 13 Week                      20/12/2015
# eLearning                         17
# DataScience                        7
# MachineLearning                   11
# ArtificialIntelligence             9
# DeepLearning                       4
# Name: 13, dtype: object
# 14 Week                      27/12/2015
# eLearning                         17
# DataScience                        7
# MachineLearning                   10
# ArtificialIntelligence             9
# DeepLearning                       3
# Name: 14, dtype: object
# 15 Week                      3/01/2016
# eLearning                        24
# DataScience                      10
# MachineLearning                  12
# ArtificialIntelligence           14
# DeepLearning                      4
# Name: 15, dtype: object
# 16 Week                      10/01/2016
# eLearning                         26
# DataScience                        9
# MachineLearning                   12
# ArtificialIntelligence            12
# DeepLearning                       4
# Name: 16, dtype: object
# 17 Week                      17/01/2016
# eLearning                         26
# DataScience                       11
# MachineLearning                   13
# ArtificialIntelligence            11
# DeepLearning                       6
# Name: 17, dtype: object
# 18 Week                      24/01/2016
# eLearning                         28
# DataScience                       11
# MachineLearning                   15
# ArtificialIntelligence            12
# DeepLearning                       7
# Name: 18, dtype: object
# 19 Week                      31/01/2016
# eLearning                         28
# DataScience                       11
# MachineLearning                   14
# ArtificialIntelligence            11
# DeepLearning                       6
# Name: 19, dtype: object
# 20 Week                      7/02/2016
# eLearning                        28
# DataScience                      10
# MachineLearning                  13
# ArtificialIntelligence           11
# DeepLearning                      5
# Name: 20, dtype: object
# 21 Week                      14/02/2016
# eLearning                         30
# DataScience                       10
# MachineLearning                   13
# ArtificialIntelligence            10
# DeepLearning                       5
# Name: 21, dtype: object
# 22 Week                      21/02/2016
# eLearning                         30
# DataScience                       10
# MachineLearning                   14
# ArtificialIntelligence            12
# DeepLearning                       5
# Name: 22, dtype: object
# 23 Week                      28/02/2016
# eLearning                         30
# DataScience                       10
# MachineLearning                   13
# ArtificialIntelligence            11
# DeepLearning                       5
# Name: 23, dtype: object
# 24 Week                      6/03/2016
# eLearning                        30
# DataScience                      10
# MachineLearning                  15
# ArtificialIntelligence           13
# DeepLearning                      7
# Name: 24, dtype: object
# 25 Week                      13/03/2016
# eLearning                         27
# DataScience                       10
# MachineLearning                   15
# ArtificialIntelligence            13
# DeepLearning                       8
# Name: 25, dtype: object
# 26 Week                      20/03/2016
# eLearning                         27
# DataScience                        9
# MachineLearning                   14
# ArtificialIntelligence            12
# DeepLearning                       6
# Name: 26, dtype: object
# 27 Week                      27/03/2016
# eLearning                         29
# DataScience                        9
# MachineLearning                   14
# ArtificialIntelligence            12
# DeepLearning                       6
# Name: 27, dtype: object
# 28 Week                      3/04/2016
# eLearning                        29
# DataScience                      10
# MachineLearning                  15
# ArtificialIntelligence           12
# DeepLearning                      7
# Name: 28, dtype: object
# 29 Week                      10/04/2016
# eLearning                         29
# DataScience                       10
# MachineLearning                   14
# ArtificialIntelligence            11
# DeepLearning                       6
# Name: 29, dtype: object
# 30 Week                      17/04/2016
# eLearning                         29
# DataScience                       10
# MachineLearning                   15
# ArtificialIntelligence            12
# DeepLearning                       6
# Name: 30, dtype: object
# 31 Week                      24/04/2016
# eLearning                         28
# DataScience                       10
# MachineLearning                   14
# ArtificialIntelligence            12
# DeepLearning                       6
# Name: 31, dtype: object
# 32 Week                      1/05/2016
# eLearning                        26
# DataScience                       9
# MachineLearning                  14
# ArtificialIntelligence           12
# DeepLearning                      6
# Name: 32, dtype: object
# 33 Week                      8/05/2016
# eLearning                        28
# DataScience                      11
# MachineLearning                  15
# ArtificialIntelligence           12
# DeepLearning                      6
# Name: 33, dtype: object
# 34 Week                      15/05/2016
# eLearning                         27
# DataScience                       10
# MachineLearning                   15
# ArtificialIntelligence            13
# DeepLearning                       7
# Name: 34, dtype: object
# 35 Week                      22/05/2016
# eLearning                         27
# DataScience                       10
# MachineLearning                   16
# ArtificialIntelligence            12
# DeepLearning                       6
# Name: 35, dtype: object
# 36 Week                      29/05/2016
# eLearning                         25
# DataScience                       10
# MachineLearning                   14
# ArtificialIntelligence            11
# DeepLearning                       6
# Name: 36, dtype: object
# 37 Week                      5/06/2016
# eLearning                        25
# DataScience                      11
# MachineLearning                  15
# ArtificialIntelligence           11
# DeepLearning                      7
# Name: 37, dtype: object
# 38 Week                      12/06/2016
# eLearning                         25
# DataScience                       10
# MachineLearning                   16
# ArtificialIntelligence            10
# DeepLearning                       6
# Name: 38, dtype: object
# 39 Week                      19/06/2016
# eLearning                         21
# DataScience                       10
# MachineLearning                   16
# ArtificialIntelligence            10
# DeepLearning                       7
# Name: 39, dtype: object
# 40 Week                      26/06/2016
# eLearning                         20
# DataScience                       10
# MachineLearning                   15
# ArtificialIntelligence            10
# DeepLearning                       7
# Name: 40, dtype: object
# 41 Week                      3/07/2016
# eLearning                        17
# DataScience                       9
# MachineLearning                  14
# ArtificialIntelligence           10
# DeepLearning                      6
# Name: 41, dtype: object
# 42 Week                      10/07/2016
# eLearning                         19
# DataScience                       10
# MachineLearning                   14
# ArtificialIntelligence             9
# DeepLearning                       6
# Name: 42, dtype: object
# 43 Week                      17/07/2016
# eLearning                         18
# DataScience                       10
# MachineLearning                   15
# ArtificialIntelligence             9
# DeepLearning                       6
# Name: 43, dtype: object
# 44 Week                      24/07/2016
# eLearning                         17
# DataScience                        9
# MachineLearning                   14
# ArtificialIntelligence             9
# DeepLearning                       6
# Name: 44, dtype: object
# 45 Week                      31/07/2016
# eLearning                         18
# DataScience                       11
# MachineLearning                   15
# ArtificialIntelligence             9
# DeepLearning                       6
# Name: 45, dtype: object
# 46 Week                      7/08/2016
# eLearning                        16
# DataScience                      10
# MachineLearning                  15
# ArtificialIntelligence            9
# DeepLearning                      6
# Name: 46, dtype: object
# 47 Week                      14/08/2016
# eLearning                         15
# DataScience                       10
# MachineLearning                   12
# ArtificialIntelligence             8
# DeepLearning                       5
# Name: 47, dtype: object
# 48 Week                      21/08/2016
# eLearning                         19
# DataScience                       12
# MachineLearning                   16
# ArtificialIntelligence            10
# DeepLearning                       6
# Name: 48, dtype: object
# 49 Week                      28/08/2016
# eLearning                         21
# DataScience                       13
# MachineLearning                   15
# ArtificialIntelligence            10
# DeepLearning                       7
# Name: 49, dtype: object
# 50 Week                      4/09/2016
# eLearning                        26
# DataScience                      13
# MachineLearning                  16
# ArtificialIntelligence           11
# DeepLearning                      6
# Name: 50, dtype: object
# 51 Week                      11/09/2016
# eLearning                         29
# DataScience                       14
# MachineLearning                   17
# ArtificialIntelligence            11
# DeepLearning                       7
# Name: 51, dtype: object
# 52 Week                      18/09/2016
# eLearning                         32
# DataScience                       14
# MachineLearning                   19
# ArtificialIntelligence            12
# DeepLearning                       6
# Name: 52, dtype: object
# 53 Week                      25/09/2016
# eLearning                         33
# DataScience                       13
# MachineLearning                   18
# ArtificialIntelligence            12
# DeepLearning                       8
# Name: 53, dtype: object
# 54 Week                      2/10/2016
# eLearning                        36
# DataScience                      12
# MachineLearning                  17
# ArtificialIntelligence           13
# DeepLearning                      8
# Name: 54, dtype: object
# 55 Week                      9/10/2016
# eLearning                        38
# DataScience                      12
# MachineLearning                  18
# ArtificialIntelligence           16
# DeepLearning                      8
# Name: 55, dtype: object
# 56 Week                      16/10/2016
# eLearning                         36
# DataScience                       13
# MachineLearning                   20
# ArtificialIntelligence            14
# DeepLearning                       8
# Name: 56, dtype: object
# 57 Week                      23/10/2016
# eLearning                         35
# DataScience                       13
# MachineLearning                   19
# ArtificialIntelligence            14
# DeepLearning                       8
# Name: 57, dtype: object
# 58 Week                      30/10/2016
# eLearning                         34
# DataScience                       13
# MachineLearning                   20
# ArtificialIntelligence            14
# DeepLearning                       8
# Name: 58, dtype: object
# 59 Week                      6/11/2016
# eLearning                        32
# DataScience                      13
# MachineLearning                  18
# ArtificialIntelligence           14
# DeepLearning                      8
# Name: 59, dtype: object
# 60 Week                      13/11/2016
# eLearning                         30
# DataScience                       13
# MachineLearning                   21
# ArtificialIntelligence            14
# DeepLearning                       9
# Name: 60, dtype: object
# 61 Week                      20/11/2016
# eLearning                         28
# DataScience                       12
# MachineLearning                   21
# ArtificialIntelligence            14
# DeepLearning                       9
# Name: 61, dtype: object
# 62 Week                      27/11/2016
# eLearning                         30
# DataScience                       14
# MachineLearning                   22
# ArtificialIntelligence            15
# DeepLearning                       9
# Name: 62, dtype: object
# 63 Week                      4/12/2016
# eLearning                        30
# DataScience                      13
# MachineLearning                  22
# ArtificialIntelligence           16
# DeepLearning                     10
# Name: 63, dtype: object
# 64 Week                      11/12/2016
# eLearning                         28
# DataScience                       14
# MachineLearning                   21
# ArtificialIntelligence            15
# DeepLearning                       9
# Name: 64, dtype: object
# 65 Week                      18/12/2016
# eLearning                         22
# DataScience                       11
# MachineLearning                   20
# ArtificialIntelligence            13
# DeepLearning                       9
# Name: 65, dtype: object
# 66 Week                      25/12/2016
# eLearning                         17
# DataScience                       10
# MachineLearning                   15
# ArtificialIntelligence            12
# DeepLearning                       7
# Name: 66, dtype: object
# 67 Week                      1/01/2017
# eLearning                        21
# DataScience                      13
# MachineLearning                  20
# ArtificialIntelligence           14
# DeepLearning                      9
# Name: 67, dtype: object
# 68 Week                      8/01/2017
# eLearning                        29
# DataScience                      15
# MachineLearning                  23
# ArtificialIntelligence           15
# DeepLearning                     10
# Name: 68, dtype: object
# 69 Week                      15/01/2017
# eLearning                         26
# DataScience                       15
# MachineLearning                   23
# ArtificialIntelligence            14
# DeepLearning                      10
# Name: 69, dtype: object
# 70 Week                      22/01/2017
# eLearning                         25
# DataScience                       15
# MachineLearning                   23
# ArtificialIntelligence            15
# DeepLearning                      10
# Name: 70, dtype: object
# 71 Week                      29/01/2017
# eLearning                         25
# DataScience                       16
# MachineLearning                   23
# ArtificialIntelligence            14
# DeepLearning                      10
# Name: 71, dtype: object
# 72 Week                      5/02/2017
# eLearning                        28
# DataScience                      16
# MachineLearning                  23
# ArtificialIntelligence           15
# DeepLearning                     10
# Name: 72, dtype: object
# 73 Week                      12/02/2017
# eLearning                         27
# DataScience                       15
# MachineLearning                   25
# ArtificialIntelligence            15
# DeepLearning                      11
# Name: 73, dtype: object
# 74 Week                      19/02/2017
# eLearning                         29
# DataScience                       16
# MachineLearning                   24
# ArtificialIntelligence            16
# DeepLearning                      11
# Name: 74, dtype: object
# 75 Week                      26/02/2017
# eLearning                         31
# DataScience                       17
# MachineLearning                   27
# ArtificialIntelligence            15
# DeepLearning                      11
# Name: 75, dtype: object
# 76 Week                      5/03/2017
# eLearning                        30
# DataScience                      16
# MachineLearning                  26
# ArtificialIntelligence           16
# DeepLearning                     11
# Name: 76, dtype: object
# 77 Week                      12/03/2017
# eLearning                         29
# DataScience                       16
# MachineLearning                   26
# ArtificialIntelligence            17
# DeepLearning                      12
# Name: 77, dtype: object
# 78 Week                      19/03/2017
# eLearning                         31
# DataScience                       16
# MachineLearning                   25
# ArtificialIntelligence            15
# DeepLearning                      11
# Name: 78, dtype: object
# 79 Week                      26/03/2017
# eLearning                         32
# DataScience                       16
# MachineLearning                   28
# ArtificialIntelligence            17
# DeepLearning                      11
# Name: 79, dtype: object
# 80 Week                      2/04/2017
# eLearning                        30
# DataScience                      17
# MachineLearning                  27
# ArtificialIntelligence           17
# DeepLearning                     12
# Name: 80, dtype: object
# 81 Week                      9/04/2017
# eLearning                        28
# DataScience                      15
# MachineLearning                  26
# ArtificialIntelligence           16
# DeepLearning                     11
# Name: 81, dtype: object
# 82 Week                      16/04/2017
# eLearning                         26
# DataScience                       16
# MachineLearning                   26
# ArtificialIntelligence            16
# DeepLearning                      12
# Name: 82, dtype: object
# 83 Week                      23/04/2017
# eLearning                         30
# DataScience                       16
# MachineLearning                   27
# ArtificialIntelligence            18
# DeepLearning                      12
# Name: 83, dtype: object
# 84 Week                      30/04/2017
# eLearning                         28
# DataScience                       15
# MachineLearning                   27
# ArtificialIntelligence            17
# DeepLearning                      11
# Name: 84, dtype: object
# 85 Week                      7/05/2017
# eLearning                        26
# DataScience                      17
# MachineLearning                  27
# ArtificialIntelligence           16
# DeepLearning                     12
# Name: 85, dtype: object
# 86 Week                      14/05/2017
# eLearning                         26
# DataScience                       16
# MachineLearning                   29
# ArtificialIntelligence            18
# DeepLearning                      12
# Name: 86, dtype: object
# 87 Week                      21/05/2017
# eLearning                         24
# DataScience                       17
# MachineLearning                   29
# ArtificialIntelligence            18
# DeepLearning                      12
# Name: 87, dtype: object
# 88 Week                      28/05/2017
# eLearning                         25
# DataScience                       16
# MachineLearning                   27
# ArtificialIntelligence            15
# DeepLearning                      11
# Name: 88, dtype: object
# 89 Week                      4/06/2017
# eLearning                        25
# DataScience                      15
# MachineLearning                  29
# ArtificialIntelligence           14
# DeepLearning                     11
# Name: 89, dtype: object
# 90 Week                      11/06/2017
# eLearning                         24
# DataScience                       16
# MachineLearning                   28
# ArtificialIntelligence            15
# DeepLearning                      11
# Name: 90, dtype: object
# 91 Week                      18/06/2017
# eLearning                         20
# DataScience                       16
# MachineLearning                   28
# ArtificialIntelligence            14
# DeepLearning                      11
# Name: 91, dtype: object
# 92 Week                      25/06/2017
# eLearning                         19
# DataScience                       16
# MachineLearning                   28
# ArtificialIntelligence            15
# DeepLearning                      12
# Name: 92, dtype: object
# 93 Week                      2/07/2017
# eLearning                        21
# DataScience                      15
# MachineLearning                  27
# ArtificialIntelligence           14
# DeepLearning                     11
# Name: 93, dtype: object
# 94 Week                      9/07/2017
# eLearning                        19
# DataScience                      16
# MachineLearning                  29
# ArtificialIntelligence           15
# DeepLearning                     12
# Name: 94, dtype: object
# 95 Week                      16/07/2017
# eLearning                         18
# DataScience                       16
# MachineLearning                   28
# ArtificialIntelligence            16
# DeepLearning                      13
# Name: 95, dtype: object
# 96 Week                      23/07/2017
# eLearning                         17
# DataScience                       17
# MachineLearning                   28
# ArtificialIntelligence            18
# DeepLearning                      12
# Name: 96, dtype: object
# 97 Week                      30/07/2017
# eLearning                         16
# DataScience                       17
# MachineLearning                   29
# ArtificialIntelligence            23
# DeepLearning                      12
# Name: 97, dtype: object
# 98 Week                      6/08/2017
# eLearning                        15
# DataScience                      17
# MachineLearning                  27
# ArtificialIntelligence           18
# DeepLearning                     13
# Name: 98, dtype: object
# 99 Week                      13/08/2017
# eLearning                         15
# DataScience                       16
# MachineLearning                   28
# ArtificialIntelligence            17
# DeepLearning                      13
# Name: 99, dtype: object
# 100 Week                      20/08/2017
# eLearning                         18
# DataScience                       18
# MachineLearning                   27
# ArtificialIntelligence            17
# DeepLearning                      12
# Name: 100, dtype: object
# 101 Week                      27/08/2017
# eLearning                         19
# DataScience                       18
# MachineLearning                   28
# ArtificialIntelligence            17
# DeepLearning                      12
# Name: 101, dtype: object
# 102 Week                      3/09/2017
# eLearning                        24
# DataScience                      19
# MachineLearning                  30
# ArtificialIntelligence           23
# DeepLearning                     13
# Name: 102, dtype: object
# 103 Week                      10/09/2017
# eLearning                         27
# DataScience                       20
# MachineLearning                   31
# ArtificialIntelligence            21
# DeepLearning                      13
# Name: 103, dtype: object
# 104 Week                      17/09/2017
# eLearning                         32
# DataScience                       20
# MachineLearning                   32
# ArtificialIntelligence            20
# DeepLearning                      14
# Name: 104, dtype: object
# 105 Week                      24/09/2017
# eLearning                         34
# DataScience                       20
# MachineLearning                   31
# ArtificialIntelligence            20
# DeepLearning                      13
# Name: 105, dtype: object
# 106 Week                      1/10/2017
# eLearning                        35
# DataScience                      19
# MachineLearning                  33
# ArtificialIntelligence           20
# DeepLearning                     13
# Name: 106, dtype: object
# 107 Week                      8/10/2017
# eLearning                        35
# DataScience                      20
# MachineLearning                  34
# ArtificialIntelligence           22
# DeepLearning                     13
# Name: 107, dtype: object
# 108 Week                      15/10/2017
# eLearning                         36
# DataScience                       20
# MachineLearning                   32
# ArtificialIntelligence            21
# DeepLearning                      14
# Name: 108, dtype: object
# 109 Week                      22/10/2017
# eLearning                         34
# DataScience                       20
# MachineLearning                   35
# ArtificialIntelligence            26
# DeepLearning                      13
# Name: 109, dtype: object
# 110 Week                      29/10/2017
# eLearning                         33
# DataScience                       21
# MachineLearning                   35
# ArtificialIntelligence            24
# DeepLearning                      14
# Name: 110, dtype: object
# 111 Week                      5/11/2017
# eLearning                        33
# DataScience                      21
# MachineLearning                  37
# ArtificialIntelligence           25
# DeepLearning                     14
# Name: 111, dtype: object
# 112 Week                      12/11/2017
# eLearning                         31
# DataScience                       20
# MachineLearning                   35
# ArtificialIntelligence            24
# DeepLearning                      15
# Name: 112, dtype: object
# 113 Week                      19/11/2017
# eLearning                         29
# DataScience                       17
# MachineLearning                   33
# ArtificialIntelligence            22
# DeepLearning                      14
# Name: 113, dtype: object
# 114 Week                      26/11/2017
# eLearning                         29
# DataScience                       19
# MachineLearning                   35
# ArtificialIntelligence            25
# DeepLearning                      15
# Name: 114, dtype: object
# 115 Week                      3/12/2017
# eLearning                        30
# DataScience                      20
# MachineLearning                  36
# ArtificialIntelligence           25
# DeepLearning                     15
# Name: 115, dtype: object
# 116 Week                      10/12/2017
# eLearning                         30
# DataScience                       20
# MachineLearning                   37
# ArtificialIntelligence            23
# DeepLearning                      15
# Name: 116, dtype: object
# 117 Week                      17/12/2017
# eLearning                         24
# DataScience                       17
# MachineLearning                   32
# ArtificialIntelligence            19
# DeepLearning                      14
# Name: 117, dtype: object
# 118 Week                      24/12/2017
# eLearning                         16
# DataScience                       14
# MachineLearning                   26
# ArtificialIntelligence            17
# DeepLearning                      12
# Name: 118, dtype: object
# 119 Week                      31/12/2017
# eLearning                         18
# DataScience                       19
# MachineLearning                   30
# ArtificialIntelligence            20
# DeepLearning                      13
# Name: 119, dtype: object
# 120 Week                      7/01/2018
# eLearning                        29
# DataScience                      22
# MachineLearning                  32
# ArtificialIntelligence           21
# DeepLearning                     15
# Name: 120, dtype: object
# 121 Week                      14/01/2018
# eLearning                         27
# DataScience                       21
# MachineLearning                   34
# ArtificialIntelligence            30
# DeepLearning                      14
# Name: 121, dtype: object
# 122 Week                      21/01/2018
# eLearning                         27
# DataScience                       21
# MachineLearning                   34
# ArtificialIntelligence            29
# DeepLearning                      14
# Name: 122, dtype: object
# 123 Week                      28/01/2018
# eLearning                         26
# DataScience                       22
# MachineLearning                   36
# ArtificialIntelligence            27
# DeepLearning                      16
# Name: 123, dtype: object
# 124 Week                      4/02/2018
# eLearning                        27
# DataScience                      20
# MachineLearning                  35
# ArtificialIntelligence           24
# DeepLearning                     15
# Name: 124, dtype: object
# 125 Week                      11/02/2018
# eLearning                         27
# DataScience                       21
# MachineLearning                   34
# ArtificialIntelligence            24
# DeepLearning                      13
# Name: 125, dtype: object
# 126 Week                      18/02/2018
# eLearning                         30
# DataScience                       21
# MachineLearning                   35
# ArtificialIntelligence            24
# DeepLearning                      14
# Name: 126, dtype: object
# 127 Week                      25/02/2018
# eLearning                         33
# DataScience                       21
# MachineLearning                   36
# ArtificialIntelligence            24
# DeepLearning                      14
# Name: 127, dtype: object
# 128 Week                      4/03/2018
# eLearning                        34
# DataScience                      22
# MachineLearning                  37
# ArtificialIntelligence           23
# DeepLearning                     14
# Name: 128, dtype: object
# 129 Week                      11/03/2018
# eLearning                         34
# DataScience                       22
# MachineLearning                   36
# ArtificialIntelligence            24
# DeepLearning                      14
# Name: 129, dtype: object
# 130 Week                      18/03/2018
# eLearning                         37
# DataScience                       23
# MachineLearning                   37
# ArtificialIntelligence            23
# DeepLearning                      15
# Name: 130, dtype: object
# 131 Week                      25/03/2018
# eLearning                         36
# DataScience                       22
# MachineLearning                   36
# ArtificialIntelligence            21
# DeepLearning                      14
# Name: 131, dtype: object
# 132 Week                      1/04/2018
# eLearning                        30
# DataScience                      22
# MachineLearning                  36
# ArtificialIntelligence           21
# DeepLearning                     14
# Name: 132, dtype: object
# 133 Week                      8/04/2018
# eLearning                        33
# DataScience                      23
# MachineLearning                  36
# ArtificialIntelligence           23
# DeepLearning                     15
# Name: 133, dtype: object
# 134 Week                      15/04/2018
# eLearning                         32
# DataScience                       21
# MachineLearning                   36
# ArtificialIntelligence            24
# DeepLearning                      15
# Name: 134, dtype: object
# 135 Week                      22/04/2018
# eLearning                         33
# DataScience                       22
# MachineLearning                   37
# ArtificialIntelligence            23
# DeepLearning                      15
# Name: 135, dtype: object
# 136 Week                      29/04/2018
# eLearning                         31
# DataScience                       22
# MachineLearning                   35
# ArtificialIntelligence            22
# DeepLearning                      14
# Name: 136, dtype: object
# 137 Week                      6/05/2018
# eLearning                        31
# DataScience                      21
# MachineLearning                  37
# ArtificialIntelligence           25
# DeepLearning                     15
# Name: 137, dtype: object
# 138 Week                      13/05/2018
# eLearning                         32
# DataScience                       22
# MachineLearning                   37
# ArtificialIntelligence            23
# DeepLearning                      15
# Name: 138, dtype: object
# 139 Week                      20/05/2018
# eLearning                         30
# DataScience                       23
# MachineLearning                   37
# ArtificialIntelligence            22
# DeepLearning                      14
# Name: 139, dtype: object
# 140 Week                      27/05/2018
# eLearning                         29
# DataScience                       22
# MachineLearning                   34
# ArtificialIntelligence            21
# DeepLearning                      14
# Name: 140, dtype: object
# 141 Week                      3/06/2018
# eLearning                        30
# DataScience                      23
# MachineLearning                  37
# ArtificialIntelligence           21
# DeepLearning                     14
# Name: 141, dtype: object
# 142 Week                      10/06/2018
# eLearning                         25
# DataScience                       21
# MachineLearning                   36
# ArtificialIntelligence            19
# DeepLearning                      14
# Name: 142, dtype: object
# 143 Week                      17/06/2018
# eLearning                         24
# DataScience                       21
# MachineLearning                   36
# ArtificialIntelligence            17
# DeepLearning                      14
# Name: 143, dtype: object
# 144 Week                      24/06/2018
# eLearning                         24
# DataScience                       21
# MachineLearning                   35
# ArtificialIntelligence            19
# DeepLearning                      14
# Name: 144, dtype: object
# 145 Week                      1/07/2018
# eLearning                        24
# DataScience                      20
# MachineLearning                  34
# ArtificialIntelligence           18
# DeepLearning                     13
# Name: 145, dtype: object
# 146 Week                      8/07/2018
# eLearning                        21
# DataScience                      23
# MachineLearning                  36
# ArtificialIntelligence           19
# DeepLearning                     14
# Name: 146, dtype: object
# 147 Week                      15/07/2018
# eLearning                         21
# DataScience                       23
# MachineLearning                   36
# ArtificialIntelligence            19
# DeepLearning                      14
# Name: 147, dtype: object
# 148 Week                      22/07/2018
# eLearning                         18
# DataScience                       22
# MachineLearning                   36
# ArtificialIntelligence            20
# DeepLearning                      13
# Name: 148, dtype: object
# 149 Week                      29/07/2018
# eLearning                         17
# DataScience                       23
# MachineLearning                   36
# ArtificialIntelligence            20
# DeepLearning                      14
# Name: 149, dtype: object
# 150 Week                      5/08/2018
# eLearning                        18
# DataScience                      23
# MachineLearning                  37
# ArtificialIntelligence           20
# DeepLearning                     13
# Name: 150, dtype: object
# 151 Week                      12/08/2018
# eLearning                         17
# DataScience                       22
# MachineLearning                   36
# ArtificialIntelligence            19
# DeepLearning                      12
# Name: 151, dtype: object
# 152 Week                      19/08/2018
# eLearning                         19
# DataScience                       24
# MachineLearning                   37
# ArtificialIntelligence            18
# DeepLearning                      14
# Name: 152, dtype: object
# 153 Week                      26/08/2018
# eLearning                         23
# DataScience                       26
# MachineLearning                   38
# ArtificialIntelligence            20
# DeepLearning                      14
# Name: 153, dtype: object
# 154 Week                      2/09/2018
# eLearning                        28
# DataScience                      27
# MachineLearning                  37
# ArtificialIntelligence           21
# DeepLearning                     14
# Name: 154, dtype: object
# 155 Week                      9/09/2018
# eLearning                        34
# DataScience                      25
# MachineLearning                  38
# ArtificialIntelligence           22
# DeepLearning                     14
# Name: 155, dtype: object
# 156 Week                      16/09/2018
# eLearning                         39
# DataScience                       25
# MachineLearning                   40
# ArtificialIntelligence            22
# DeepLearning                      15
# Name: 156, dtype: object
# 157 Week                      23/09/2018
# eLearning                         38
# DataScience                       25
# MachineLearning                   39
# ArtificialIntelligence            23
# DeepLearning                      15
# Name: 157, dtype: object
# 158 Week                      30/09/2018
# eLearning                         44
# DataScience                       26
# MachineLearning                   39
# ArtificialIntelligence            21
# DeepLearning                      15
# Name: 158, dtype: object
# 159 Week                      7/10/2018
# eLearning                        43
# DataScience                      26
# MachineLearning                  39
# ArtificialIntelligence           22
# DeepLearning                     15
# Name: 159, dtype: object
# 160 Week                      14/10/2018
# eLearning                         45
# DataScience                       26
# MachineLearning                   39
# ArtificialIntelligence            23
# DeepLearning                      15
# Name: 160, dtype: object
# 161 Week                      21/10/2018
# eLearning                         42
# DataScience                       26
# MachineLearning                   40
# ArtificialIntelligence            24
# DeepLearning                      15
# Name: 161, dtype: object
# 162 Week                      28/10/2018
# eLearning                         39
# DataScience                       24
# MachineLearning                   39
# ArtificialIntelligence            23
# DeepLearning                      15
# Name: 162, dtype: object
# 163 Week                      4/11/2018
# eLearning                        37
# DataScience                      24
# MachineLearning                  36
# ArtificialIntelligence           21
# DeepLearning                     15
# Name: 163, dtype: object
# 164 Week                      11/11/2018
# eLearning                         41
# DataScience                       26
# MachineLearning                   39
# ArtificialIntelligence            25
# DeepLearning                      15
# Name: 164, dtype: object
# 165 Week                      18/11/2018
# eLearning                         35
# DataScience                       23
# MachineLearning                   37
# ArtificialIntelligence            22
# DeepLearning                      14
# Name: 165, dtype: object
# 166 Week                      25/11/2018
# eLearning                         38
# DataScience                       26
# MachineLearning                   41
# ArtificialIntelligence            24
# DeepLearning                      15
# Name: 166, dtype: object
# 167 Week                      2/12/2018
# eLearning                        38
# DataScience                      26
# MachineLearning                  42
# ArtificialIntelligence           24
# DeepLearning                     16
# Name: 167, dtype: object
# 168 Week                      9/12/2018
# eLearning                        35
# DataScience                      26
# MachineLearning                  40
# ArtificialIntelligence           22
# DeepLearning                     15
# Name: 168, dtype: object
# 169 Week                      16/12/2018
# eLearning                         30
# DataScience                       23
# MachineLearning                   37
# ArtificialIntelligence            23
# DeepLearning                      13
# Name: 169, dtype: object
# 170 Week                      23/12/2018
# eLearning                         19
# DataScience                       19
# MachineLearning                   28
# ArtificialIntelligence            17
# DeepLearning                      10
# Name: 170, dtype: object
# 171 Week                      30/12/2018
# eLearning                         20
# DataScience                       22
# MachineLearning                   31
# ArtificialIntelligence            18
# DeepLearning                      11
# Name: 171, dtype: object
# 172 Week                      6/01/2019
# eLearning                        30
# DataScience                      29
# MachineLearning                  37
# ArtificialIntelligence           22
# DeepLearning                     14
# Name: 172, dtype: object
# 173 Week                      13/01/2019
# eLearning                         31
# DataScience                       29
# MachineLearning                   37
# ArtificialIntelligence            24
# DeepLearning                      15
# Name: 173, dtype: object
# 174 Week                      20/01/2019
# eLearning                         30
# DataScience                       28
# MachineLearning                   39
# ArtificialIntelligence            22
# DeepLearning                      15
# Name: 174, dtype: object
# 175 Week                      27/01/2019
# eLearning                         29
# DataScience                       28
# MachineLearning                   40
# ArtificialIntelligence            23
# DeepLearning                      15
# Name: 175, dtype: object
# 176 Week                      3/02/2019
# eLearning                        29
# DataScience                      29
# MachineLearning                  41
# ArtificialIntelligence           23
# DeepLearning                     15
# Name: 176, dtype: object
# 177 Week                      10/02/2019
# eLearning                         32
# DataScience                       28
# MachineLearning                   40
# ArtificialIntelligence            24
# DeepLearning                      15
# Name: 177, dtype: object
# 178 Week                      17/02/2019
# eLearning                         35
# DataScience                       30
# MachineLearning                   42
# ArtificialIntelligence            25
# DeepLearning                      15
# Name: 178, dtype: object
# 179 Week                      24/02/2019
# eLearning                         38
# DataScience                       29
# MachineLearning                   41
# ArtificialIntelligence            23
# DeepLearning                      15
# Name: 179, dtype: object
# 180 Week                      3/03/2019
# eLearning                        36
# DataScience                      28
# MachineLearning                  42
# ArtificialIntelligence           23
# DeepLearning                     15
# Name: 180, dtype: object
# 181 Week                      10/03/2019
# eLearning                         39
# DataScience                       27
# MachineLearning                   40
# ArtificialIntelligence            23
# DeepLearning                      15
# Name: 181, dtype: object
# 182 Week                      17/03/2019
# eLearning                         41
# DataScience                       28
# MachineLearning                   41
# ArtificialIntelligence            23
# DeepLearning                      14
# Name: 182, dtype: object
# 183 Week                      24/03/2019
# eLearning                         38
# DataScience                       30
# MachineLearning                   41
# ArtificialIntelligence            24
# DeepLearning                      16
# Name: 183, dtype: object
# 184 Week                      31/03/2019
# eLearning                         41
# DataScience                       29
# MachineLearning                   41
# ArtificialIntelligence            23
# DeepLearning                      15
# Name: 184, dtype: object
# 185 Week                      7/04/2019
# eLearning                        38
# DataScience                      28
# MachineLearning                  41
# ArtificialIntelligence           23
# DeepLearning                     16
# Name: 185, dtype: object
# 186 Week                      14/04/2019
# eLearning                         36
# DataScience                       27
# MachineLearning                   37
# ArtificialIntelligence            21
# DeepLearning                      14
# Name: 186, dtype: object
# 187 Week                      21/04/2019
# eLearning                         36
# DataScience                       27
# MachineLearning                   39
# ArtificialIntelligence            23
# DeepLearning                      15
# Name: 187, dtype: object
# 188 Week                      28/04/2019
# eLearning                         36
# DataScience                       27
# MachineLearning                   39
# ArtificialIntelligence            24
# DeepLearning                      14
# Name: 188, dtype: object
# 189 Week                      5/05/2019
# eLearning                        36
# DataScience                      28
# MachineLearning                  41
# ArtificialIntelligence           23
# DeepLearning                     14
# Name: 189, dtype: object
# 190 Week                      12/05/2019
# eLearning                         37
# DataScience                       29
# MachineLearning                   41
# ArtificialIntelligence            24
# DeepLearning                      15
# Name: 190, dtype: object
# 191 Week                      19/05/2019
# eLearning                         35
# DataScience                       30
# MachineLearning                   39
# ArtificialIntelligence            22
# DeepLearning                      15
# Name: 191, dtype: object
# 192 Week                      26/05/2019
# eLearning                         32
# DataScience                       29
# MachineLearning                   38
# ArtificialIntelligence            21
# DeepLearning                      14
# Name: 192, dtype: object
# 193 Week                      2/06/2019
# eLearning                        27
# ...
# Name: 196, dtype: object
# 197 Week                      30/06/2019
# eLearning                         32
# DataScience                       29
# MachineLearning                   40
# ArtificialIntelligence            21
# DeepLearning                      14
# Name: 197, dtype: object
# 198 Week                      7/07/2019
# eLearning                        27
# DataScience                      31
# MachineLearning                  40
# ArtificialIntelligence           22
# DeepLearning                     15
# Name: 198, dtype: object
# 199 Week                      14/07/2019
# eLearning                         23
# DataScience                       31
# MachineLearning                   41
# ArtificialIntelligence            23
# DeepLearning                      15
# Name: 199, dtype: object
# 200 Week                      21/07/2019
# eLearning                         22
# DataScience                       31
# MachineLearning                   40
# ArtificialIntelligence            22
# DeepLearning                      14
# Name: 200, dtype: object
# 201 Week                      28/07/2019
# eLearning                         20
# DataScience                       31
# MachineLearning                   39
# ArtificialIntelligence            22
# DeepLearning                      13
# Name: 201, dtype: object
# 202 Week                      4/08/2019
# eLearning                        20
# DataScience                      30
# MachineLearning                  38
# ArtificialIntelligence           21
# DeepLearning                     14
# Name: 202, dtype: object
# 203 Week                      11/08/2019
# eLearning                         19
# DataScience                       31
# MachineLearning                   39
# ArtificialIntelligence            21
# DeepLearning                      14
# Name: 203, dtype: object
# 204 Week                      18/08/2019
# eLearning                         26
# DataScience                       35
# MachineLearning                   43
# ArtificialIntelligence            22
# DeepLearning                      14
# Name: 204, dtype: object
# 205 Week                      25/08/2019
# eLearning                         27
# DataScience                       37
# MachineLearning                   43
# ArtificialIntelligence            22
# DeepLearning                      14
# Name: 205, dtype: object
# 206 Week                      1/09/2019
# eLearning                        33
# DataScience                      34
# MachineLearning                  40
# ArtificialIntelligence           22
# DeepLearning                     15
# Name: 206, dtype: object
# 207 Week                      8/09/2019
# eLearning                        42
# DataScience                      36
# MachineLearning                  44
# ArtificialIntelligence           25
# DeepLearning                     15
# Name: 207, dtype: object
# 208 Week                      15/09/2019
# eLearning                         44
# DataScience                       37
# MachineLearning                   45
# ArtificialIntelligence            25
# DeepLearning                      15
# Name: 208, dtype: object
# 209 Week                      22/09/2019
# eLearning                         45
# DataScience                       35
# MachineLearning                   46
# ArtificialIntelligence            26
# DeepLearning                      15
# Name: 209, dtype: object
# 210 Week                      29/09/2019
# eLearning                         55
# DataScience                       34
# MachineLearning                   43
# ArtificialIntelligence            23
# DeepLearning                      15
# Name: 210, dtype: object
# 211 Week                      6/10/2019
# eLearning                        53
# DataScience                      34
# MachineLearning                  43
# ArtificialIntelligence           24
# DeepLearning                     15
# Name: 211, dtype: object
# 212 Week                      13/10/2019
# eLearning                         55
# DataScience                       34
# MachineLearning                   44
# ArtificialIntelligence            24
# DeepLearning                      15
# Name: 212, dtype: object
# 213 Week                      20/10/2019
# eLearning                         52
# DataScience                       32
# MachineLearning                   42
# ArtificialIntelligence            23
# DeepLearning                      14
# Name: 213, dtype: object
# 214 Week                      27/10/2019
# eLearning                         48
# DataScience                       31
# MachineLearning                   39
# ArtificialIntelligence            22
# DeepLearning                      14
# Name: 214, dtype: object
# 215 Week                      3/11/2019
# eLearning                        49
# DataScience                      34
# MachineLearning                  44
# ArtificialIntelligence           25
# DeepLearning                     14
# Name: 215, dtype: object
# 216 Week                      10/11/2019
# eLearning                         47
# DataScience                       33
# MachineLearning                   43
# ArtificialIntelligence            24
# DeepLearning                      15
# Name: 216, dtype: object
# 217 Week                      17/11/2019
# eLearning                         46
# DataScience                       34
# MachineLearning                   45
# ArtificialIntelligence            27
# DeepLearning                      15
# Name: 217, dtype: object
# 218 Week                      24/11/2019
# eLearning                         42
# DataScience                       30
# MachineLearning                   41
# ArtificialIntelligence            24
# DeepLearning                      15
# Name: 218, dtype: object
# 219 Week                      1/12/2019
# eLearning                        43
# DataScience                      34
# MachineLearning                  43
# ArtificialIntelligence           24
# DeepLearning                     14
# Name: 219, dtype: object
# 220 Week                      8/12/2019
# eLearning                        43
# DataScience                      32
# MachineLearning                  44
# ArtificialIntelligence           25
# DeepLearning                     15
# Name: 220, dtype: object
# 221 Week                      15/12/2019
# eLearning                         38
# DataScience                       32
# MachineLearning                   42
# ArtificialIntelligence            22
# DeepLearning                      15
# Name: 221, dtype: object
# 222 Week                      22/12/2019
# eLearning                         24
# DataScience                       26
# MachineLearning                   33
# ArtificialIntelligence            17
# DeepLearning                      11
# Name: 222, dtype: object
# 223 Week                      29/12/2019
# eLearning                         23
# DataScience                       29
# MachineLearning                   33
# ArtificialIntelligence            19
# DeepLearning                      12
# Name: 223, dtype: object
# 224 Week                      5/01/2020
# eLearning                        38
# DataScience                      35
# MachineLearning                  42
# ArtificialIntelligence           25
# DeepLearning                     15
# Name: 224, dtype: object
# 225 Week                      12/01/2020
# eLearning                         34
# DataScience                       35
# MachineLearning                   42
# ArtificialIntelligence            25
# DeepLearning                      15
# Name: 225, dtype: object
# 226 Week                      19/01/2020
# eLearning                         31
# DataScience                       36
# MachineLearning                   44
# ArtificialIntelligence            24
# DeepLearning                      14
# Name: 226, dtype: object
# 227 Week                      26/01/2020
# eLearning                         30
# DataScience                       35
# MachineLearning                   43
# ArtificialIntelligence            24
# DeepLearning                      14
# Name: 227, dtype: object
# 228 Week                      2/02/2020
# eLearning                        34
# DataScience                      36
# MachineLearning                  44
# ArtificialIntelligence           24
# DeepLearning                     15
# Name: 228, dtype: object
# 229 Week                      9/02/2020
# eLearning                        37
# DataScience                      38
# MachineLearning                  44
# ArtificialIntelligence           25
# DeepLearning                     16
# Name: 229, dtype: object
# 230 Week                      16/02/2020
# eLearning                         43
# DataScience                       38
# MachineLearning                   46
# ArtificialIntelligence            26
# DeepLearning                      16
# Name: 230, dtype: object
# 231 Week                      23/02/2020
# eLearning                         42
# DataScience                       38
# MachineLearning                   46
# ArtificialIntelligence            26
# DeepLearning                      16
# Name: 231, dtype: object
# 232 Week                      1/03/2020
# eLearning                        48
# DataScience                      37
# MachineLearning                  44
# ArtificialIntelligence           25
# DeepLearning                     15
# Name: 232, dtype: object
# 233 Week                      8/03/2020
# eLearning                        57
# DataScience                      34
# MachineLearning                  39
# ArtificialIntelligence           23
# DeepLearning                     14
# Name: 233, dtype: object
# 234 Week                      15/03/2020
# eLearning                         98
# DataScience                       29
# MachineLearning                   34
# ArtificialIntelligence            19
# DeepLearning                      12
# Name: 234, dtype: object
# 235 Week                      22/03/2020
# eLearning                        100
# DataScience                       28
# MachineLearning                   33
# ArtificialIntelligence            19
# DeepLearning                      12
# Name: 235, dtype: object
# 236 Week                      29/03/2020
# eLearning                         97
# DataScience                       30
# MachineLearning                   35
# ArtificialIntelligence            19
# DeepLearning                      13
# Name: 236, dtype: object
# 237 Week                      5/04/2020
# eLearning                       100
# DataScience                      32
# MachineLearning                  38
# ArtificialIntelligence           21
# DeepLearning                     13
# Name: 237, dtype: object
# 238 Week                      12/04/2020
# eLearning                         94
# DataScience                       34
# MachineLearning                   41
# ArtificialIntelligence            22
# DeepLearning                      14
# Name: 238, dtype: object
# 239 Week                      19/04/2020
# eLearning                         98
# DataScience                       32
# MachineLearning                   41
# ArtificialIntelligence            21
# DeepLearning                      15
# Name: 239, dtype: object
# 240 Week                      26/04/2020
# eLearning                         86
# DataScience                       33
# MachineLearning                   41
# ArtificialIntelligence            20
# DeepLearning                      15
# Name: 240, dtype: object
# 241 Week                      3/05/2020
# eLearning                        86
# DataScience                      31
# MachineLearning                  41
# ArtificialIntelligence           22
# DeepLearning                     15
# Name: 241, dtype: object
# 242 Week                      10/05/2020
# eLearning                         83
# DataScience                       33
# MachineLearning                   40
# ArtificialIntelligence            22
# DeepLearning                      15
# Name: 242, dtype: object
# 243 Week                      17/05/2020
# eLearning                         66
# DataScience                       33
# MachineLearning                   40
# ArtificialIntelligence            21
# DeepLearning                      15
# Name: 243, dtype: object
# 244 Week                      24/05/2020
# eLearning                         57
# DataScience                       32
# MachineLearning                   40
# ArtificialIntelligence            20
# DeepLearning                      15
# Name: 244, dtype: object
# 245 Week                      31/05/2020
# eLearning                         65
# DataScience                       33
# MachineLearning                   41
# ArtificialIntelligence            21
# DeepLearning                      14
# Name: 245, dtype: object
# 246 Week                      7/06/2020
# eLearning                        69
# DataScience                      33
# MachineLearning                  41
# ArtificialIntelligence           20
# DeepLearning                     15
# Name: 246, dtype: object
# 247 Week                      14/06/2020
# eLearning                         61
# DataScience                       33
# MachineLearning                   40
# ArtificialIntelligence            21
# DeepLearning                      15
# Name: 247, dtype: object
# 248 Week                      21/06/2020
# eLearning                         61
# DataScience                       34
# MachineLearning                   41
# ArtificialIntelligence            20
# DeepLearning                      14
# Name: 248, dtype: object
# 249 Week                      28/06/2020
# eLearning                         59
# DataScience                       35
# MachineLearning                   38
# ArtificialIntelligence            20
# DeepLearning                      14
# Name: 249, dtype: object
# 250 Week                      5/07/2020
# eLearning                        55
# DataScience                      35
# MachineLearning                  39
# ArtificialIntelligence           19
# DeepLearning                     14
# Name: 250, dtype: object
# 251 Week                      12/07/2020
# eLearning                         58
# DataScience                       36
# MachineLearning                   40
# ArtificialIntelligence            21
# DeepLearning                      15
# Name: 251, dtype: object
# 252 Week                      19/07/2020
# eLearning                         55
# DataScience                       36
# MachineLearning                   40
# ArtificialIntelligence            21
# DeepLearning                      14
# Name: 252, dtype: object
# 253 Week                      26/07/2020
# eLearning                         43
# DataScience                       34
# MachineLearning                   39
# ArtificialIntelligence            20
# DeepLearning                      14
# Name: 253, dtype: object
# 254 Week                      2/08/2020
# eLearning                        44
# DataScience                      34
# MachineLearning                  37
# ArtificialIntelligence           20
# DeepLearning                     13
# Name: 254, dtype: object
# 255 Week                      9/08/2020
# eLearning                        44
# DataScience                      35
# MachineLearning                  38
# ArtificialIntelligence           21
# DeepLearning                     13
# Name: 255, dtype: object
# 256 Week                      16/08/2020
# eLearning                         41
# DataScience                       36
# MachineLearning                   40
# ArtificialIntelligence            22
# DeepLearning                      14
# Name: 256, dtype: object
# 257 Week                      23/08/2020
# eLearning                         49
# DataScience                       39
# MachineLearning                   40
# ArtificialIntelligence            21
# DeepLearning                      14
# Name: 257, dtype: object
# 258 Week                      30/08/2020
# eLearning                         62
# DataScience                       37
# MachineLearning                   40
# ArtificialIntelligence            21
# DeepLearning                      14
# Name: 258, dtype: object
# 259 Week                      6/09/2020
# eLearning                        74
# DataScience                      38
# MachineLearning                  42
# ArtificialIntelligence           24
# DeepLearning                     14
# Name: 259, dtype: object
# 260 Week                      13/09/2020
# eLearning                         80
# DataScience                       39
# MachineLearning                   39
# ArtificialIntelligence            21
# DeepLearning                      14
# Name: 260, dtype: object

# %% [markdown]
# 1b. Iterates through each column as key value pair

# %%
for key,value in trend_data.iteritems():
   print(key,value)
# Out:
# Week 0      20/09/2015
# 1      27/09/2015
# 2       4/10/2015
# 3      11/10/2015
# 4      18/10/2015
#           ...
# 256    16/08/2020
# 257    23/08/2020
# 258    30/08/2020
# 259     6/09/2020
# 260    13/09/2020
# Name: Week, Length: 261, dtype: object
# eLearning 0      32
# 1      35
# 2      38
# 3      37
# 4      38
#        ..
# 256    41
# 257    49
# 258    62
# 259    74
# 260    80
# Name: eLearning, Length: 261, dtype: int64
# DataScience 0       9
# 1      10
# 2      10
# 3       9
# 4       9
#        ..
# 256    36
# 257    39
# 258    37
# 259    38
# 260    39
# Name: DataScience, Length: 261, dtype: int64
# MachineLearning 0      11
# 1      11
# 2      12
# 3      12
# 4      12
#        ..
# 256    40
# 257    40
# 258    40
# 259    42
# 260    39
# Name: MachineLearning, Length: 261, dtype: int64
# ArtificialIntelligence 0      11
# 1      11
# 2      11
# 3      10
# 4      10
#        ..
# 256    22
# 257    21
# 258    21
# 259    24
# 260    21
# Name: ArtificialIntelligence, Length: 261, dtype: int64
# DeepLearning 0       4
# 1       4
# 2       4
# 3       4
# 4       4
#        ..
# 256    14
# 257    14
# 258    14
# 259    14
# 260    14
# Name: DeepLearning, Length: 261, dtype: int64

# %% [markdown]
# 1c. Considers each row as a tuple and iterates through them

# %%
for row_tuple in trend_data.itertuples():
    print(row_tuple)
# Out:
# Pandas(Index=0, Week='20/09/2015', eLearning=32, DataScience=9, MachineLearning=11, ArtificialIntelligence=11, DeepLearning=4)
# Pandas(Index=1, Week='27/09/2015', eLearning=35, DataScience=10, MachineLearning=11, ArtificialIntelligence=11, DeepLearning=4)
# Pandas(Index=2, Week='4/10/2015', eLearning=38, DataScience=10, MachineLearning=12, ArtificialIntelligence=11, DeepLearning=4)
# Pandas(Index=3, Week='11/10/2015', eLearning=37, DataScience=9, MachineLearning=12, ArtificialIntelligence=10, DeepLearning=4)
# Pandas(Index=4, Week='18/10/2015', eLearning=38, DataScience=9, MachineLearning=12, ArtificialIntelligence=10, DeepLearning=4)
# Pandas(Index=5, Week='25/10/2015', eLearning=38, DataScience=10, MachineLearning=12, ArtificialIntelligence=11, DeepLearning=4)
# Pandas(Index=6, Week='1/11/2015', eLearning=37, DataScience=9, MachineLearning=13, ArtificialIntelligence=11, DeepLearning=3)
# Pandas(Index=7, Week='8/11/2015', eLearning=35, DataScience=8, MachineLearning=14, ArtificialIntelligence=12, DeepLearning=5)
# Pandas(Index=8, Week='15/11/2015', eLearning=35, DataScience=9, MachineLearning=13, ArtificialIntelligence=12, DeepLearning=4)
# Pandas(Index=9, Week='22/11/2015', eLearning=31, DataScience=8, MachineLearning=12, ArtificialIntelligence=10, DeepLearning=4)
# Pandas(Index=10, Week='29/11/2015', eLearning=35, DataScience=9, MachineLearning=13, ArtificialIntelligence=11, DeepLearning=4)
# Pandas(Index=11, Week='6/12/2015', eLearning=33, DataScience=9, MachineLearning=13, ArtificialIntelligence=12, DeepLearning=5)
# Pandas(Index=12, Week='13/12/2015', eLearning=30, DataScience=9, MachineLearning=14, ArtificialIntelligence=11, DeepLearning=5)
# Pandas(Index=13, Week='20/12/2015', eLearning=17, DataScience=7, MachineLearning=11, ArtificialIntelligence=9, DeepLearning=4)
# Pandas(Index=14, Week='27/12/2015', eLearning=17, DataScience=7, MachineLearning=10, ArtificialIntelligence=9, DeepLearning=3)
# Pandas(Index=15, Week='3/01/2016', eLearning=24, DataScience=10, MachineLearning=12, ArtificialIntelligence=14, DeepLearning=4)
# Pandas(Index=16, Week='10/01/2016', eLearning=26, DataScience=9, MachineLearning=12, ArtificialIntelligence=12, DeepLearning=4)
# Pandas(Index=17, Week='17/01/2016', eLearning=26, DataScience=11, MachineLearning=13, ArtificialIntelligence=11, DeepLearning=6)
# Pandas(Index=18, Week='24/01/2016', eLearning=28, DataScience=11, MachineLearning=15, ArtificialIntelligence=12, DeepLearning=7)
# Pandas(Index=19, Week='31/01/2016', eLearning=28, DataScience=11, MachineLearning=14, ArtificialIntelligence=11, DeepLearning=6)
# Pandas(Index=20, Week='7/02/2016', eLearning=28, DataScience=10, MachineLearning=13, ArtificialIntelligence=11, DeepLearning=5)
# Pandas(Index=21, Week='14/02/2016', eLearning=30, DataScience=10, MachineLearning=13, ArtificialIntelligence=10, DeepLearning=5)
# Pandas(Index=22, Week='21/02/2016', eLearning=30, DataScience=10, MachineLearning=14, ArtificialIntelligence=12, DeepLearning=5)
# Pandas(Index=23, Week='28/02/2016', eLearning=30, DataScience=10, MachineLearning=13, ArtificialIntelligence=11, DeepLearning=5)
# Pandas(Index=24, Week='6/03/2016', eLearning=30, DataScience=10, MachineLearning=15, ArtificialIntelligence=13, DeepLearning=7)
# Pandas(Index=25, Week='13/03/2016', eLearning=27, DataScience=10, MachineLearning=15, ArtificialIntelligence=13, DeepLearning=8)
# Pandas(Index=26, Week='20/03/2016', eLearning=27, DataScience=9, MachineLearning=14, ArtificialIntelligence=12, DeepLearning=6)
# Pandas(Index=27, Week='27/03/2016', eLearning=29, DataScience=9, MachineLearning=14, ArtificialIntelligence=12, DeepLearning=6)
# Pandas(Index=28, Week='3/04/2016', eLearning=29, DataScience=10, MachineLearning=15, ArtificialIntelligence=12, DeepLearning=7)
# Pandas(Index=29, Week='10/04/2016', eLearning=29, DataScience=10, MachineLearning=14, ArtificialIntelligence=11, DeepLearning=6)
# Pandas(Index=30, Week='17/04/2016', eLearning=29, DataScience=10, MachineLearning=15, ArtificialIntelligence=12, DeepLearning=6)
# Pandas(Index=31, Week='24/04/2016', eLearning=28, DataScience=10, MachineLearning=14, ArtificialIntelligence=12, DeepLearning=6)
# Pandas(Index=32, Week='1/05/2016', eLearning=26, DataScience=9, MachineLearning=14, ArtificialIntelligence=12, DeepLearning=6)
# Pandas(Index=33, Week='8/05/2016', eLearning=28, DataScience=11, MachineLearning=15, ArtificialIntelligence=12, DeepLearning=6)
# Pandas(Index=34, Week='15/05/2016', eLearning=27, DataScience=10, MachineLearning=15, ArtificialIntelligence=13, DeepLearning=7)
# Pandas(Index=35, Week='22/05/2016', eLearning=27, DataScience=10, MachineLearning=16, ArtificialIntelligence=12, DeepLearning=6)
# Pandas(Index=36, Week='29/05/2016', eLearning=25, DataScience=10, MachineLearning=14, ArtificialIntelligence=11, DeepLearning=6)
# Pandas(Index=37, Week='5/06/2016', eLearning=25, DataScience=11, MachineLearning=15, ArtificialIntelligence=11, DeepLearning=7)
# Pandas(Index=38, Week='12/06/2016', eLearning=25, DataScience=10, MachineLearning=16, ArtificialIntelligence=10, DeepLearning=6)
# Pandas(Index=39, Week='19/06/2016', eLearning=21, DataScience=10, MachineLearning=16, ArtificialIntelligence=10, DeepLearning=7)
# Pandas(Index=40, Week='26/06/2016', eLearning=20, DataScience=10, MachineLearning=15, ArtificialIntelligence=10, DeepLearning=7)
# Pandas(Index=41, Week='3/07/2016', eLearning=17, DataScience=9, MachineLearning=14, ArtificialIntelligence=10, DeepLearning=6)
# Pandas(Index=42, Week='10/07/2016', eLearning=19, DataScience=10, MachineLearning=14, ArtificialIntelligence=9, DeepLearning=6)
# Pandas(Index=43, Week='17/07/2016', eLearning=18, DataScience=10, MachineLearning=15, ArtificialIntelligence=9, DeepLearning=6)
# Pandas(Index=44, Week='24/07/2016', eLearning=17, DataScience=9, MachineLearning=14, ArtificialIntelligence=9, DeepLearning=6)
# Pandas(Index=45, Week='31/07/2016', eLearning=18, DataScience=11, MachineLearning=15, ArtificialIntelligence=9, DeepLearning=6)
# Pandas(Index=46, Week='7/08/2016', eLearning=16, DataScience=10, MachineLearning=15, ArtificialIntelligence=9, DeepLearning=6)
# Pandas(Index=47, Week='14/08/2016', eLearning=15, DataScience=10, MachineLearning=12, ArtificialIntelligence=8, DeepLearning=5)
# Pandas(Index=48, Week='21/08/2016', eLearning=19, DataScience=12, MachineLearning=16, ArtificialIntelligence=10, DeepLearning=6)
# Pandas(Index=49, Week='28/08/2016', eLearning=21, DataScience=13, MachineLearning=15, ArtificialIntelligence=10, DeepLearning=7)
# Pandas(Index=50, Week='4/09/2016', eLearning=26, DataScience=13, MachineLearning=16, ArtificialIntelligence=11, DeepLearning=6)
# Pandas(Index=51, Week='11/09/2016', eLearning=29, DataScience=14, MachineLearning=17, ArtificialIntelligence=11, DeepLearning=7)
# Pandas(Index=52, Week='18/09/2016', eLearning=32, DataScience=14, MachineLearning=19, ArtificialIntelligence=12, DeepLearning=6)
# Pandas(Index=53, Week='25/09/2016', eLearning=33, DataScience=13, MachineLearning=18, ArtificialIntelligence=12, DeepLearning=8)
# Pandas(Index=54, Week='2/10/2016', eLearning=36, DataScience=12, MachineLearning=17, ArtificialIntelligence=13, DeepLearning=8)
# Pandas(Index=55, Week='9/10/2016', eLearning=38, DataScience=12, MachineLearning=18, ArtificialIntelligence=16, DeepLearning=8)
# Pandas(Index=56, Week='16/10/2016', eLearning=36, DataScience=13, MachineLearning=20, ArtificialIntelligence=14, DeepLearning=8)
# Pandas(Index=57, Week='23/10/2016', eLearning=35, DataScience=13, MachineLearning=19, ArtificialIntelligence=14, DeepLearning=8)
# Pandas(Index=58, Week='30/10/2016', eLearning=34, DataScience=13, MachineLearning=20, ArtificialIntelligence=14, DeepLearning=8)
# Pandas(Index=59, Week='6/11/2016', eLearning=32, DataScience=13, MachineLearning=18, ArtificialIntelligence=14, DeepLearning=8)
# Pandas(Index=60, Week='13/11/2016', eLearning=30, DataScience=13, MachineLearning=21, ArtificialIntelligence=14, DeepLearning=9)
# Pandas(Index=61, Week='20/11/2016', eLearning=28, DataScience=12, MachineLearning=21, ArtificialIntelligence=14, DeepLearning=9)
# Pandas(Index=62, Week='27/11/2016', eLearning=30, DataScience=14, MachineLearning=22, ArtificialIntelligence=15, DeepLearning=9)
# Pandas(Index=63, Week='4/12/2016', eLearning=30, DataScience=13, MachineLearning=22, ArtificialIntelligence=16, DeepLearning=10)
# Pandas(Index=64, Week='11/12/2016', eLearning=28, DataScience=14, MachineLearning=21, ArtificialIntelligence=15, DeepLearning=9)
# Pandas(Index=65, Week='18/12/2016', eLearning=22, DataScience=11, MachineLearning=20, ArtificialIntelligence=13, DeepLearning=9)
# Pandas(Index=66, Week='25/12/2016', eLearning=17, DataScience=10, MachineLearning=15, ArtificialIntelligence=12, DeepLearning=7)
# Pandas(Index=67, Week='1/01/2017', eLearning=21, DataScience=13, MachineLearning=20, ArtificialIntelligence=14, DeepLearning=9)
# Pandas(Index=68, Week='8/01/2017', eLearning=29, DataScience=15, MachineLearning=23, ArtificialIntelligence=15, DeepLearning=10)
# Pandas(Index=69, Week='15/01/2017', eLearning=26, DataScience=15, MachineLearning=23, ArtificialIntelligence=14, DeepLearning=10)
# Pandas(Index=70, Week='22/01/2017', eLearning=25, DataScience=15, MachineLearning=23, ArtificialIntelligence=15, DeepLearning=10)
# Pandas(Index=71, Week='29/01/2017', eLearning=25, DataScience=16, MachineLearning=23, ArtificialIntelligence=14, DeepLearning=10)
# Pandas(Index=72, Week='5/02/2017', eLearning=28, DataScience=16, MachineLearning=23, ArtificialIntelligence=15, DeepLearning=10)
# Pandas(Index=73, Week='12/02/2017', eLearning=27, DataScience=15, MachineLearning=25, ArtificialIntelligence=15, DeepLearning=11)
# Pandas(Index=74, Week='19/02/2017', eLearning=29, DataScience=16, MachineLearning=24, ArtificialIntelligence=16, DeepLearning=11)
# Pandas(Index=75, Week='26/02/2017', eLearning=31, DataScience=17, MachineLearning=27, ArtificialIntelligence=15, DeepLearning=11)
# Pandas(Index=76, Week='5/03/2017', eLearning=30, DataScience=16, MachineLearning=26, ArtificialIntelligence=16, DeepLearning=11)
# Pandas(Index=77, Week='12/03/2017', eLearning=29, DataScience=16, MachineLearning=26, ArtificialIntelligence=17, DeepLearning=12)
# Pandas(Index=78, Week='19/03/2017', eLearning=31, DataScience=16, MachineLearning=25, ArtificialIntelligence=15, DeepLearning=11)
# Pandas(Index=79, Week='26/03/2017', eLearning=32, DataScience=16, MachineLearning=28, ArtificialIntelligence=17, DeepLearning=11)
# Pandas(Index=80, Week='2/04/2017', eLearning=30, DataScience=17, MachineLearning=27, ArtificialIntelligence=17, DeepLearning=12)
# Pandas(Index=81, Week='9/04/2017', eLearning=28, DataScience=15, MachineLearning=26, ArtificialIntelligence=16, DeepLearning=11)
# Pandas(Index=82, Week='16/04/2017', eLearning=26, DataScience=16, MachineLearning=26, ArtificialIntelligence=16, DeepLearning=12)
# Pandas(Index=83, Week='23/04/2017', eLearning=30, DataScience=16, MachineLearning=27, ArtificialIntelligence=18, DeepLearning=12)
# Pandas(Index=84, Week='30/04/2017', eLearning=28, DataScience=15, MachineLearning=27, ArtificialIntelligence=17, DeepLearning=11)
# Pandas(Index=85, Week='7/05/2017', eLearning=26, DataScience=17, MachineLearning=27, ArtificialIntelligence=16, DeepLearning=12)
# Pandas(Index=86, Week='14/05/2017', eLearning=26, DataScience=16, MachineLearning=29, ArtificialIntelligence=18, DeepLearning=12)
# Pandas(Index=87, Week='21/05/2017', eLearning=24, DataScience=17, MachineLearning=29, ArtificialIntelligence=18, DeepLearning=12)
# Pandas(Index=88, Week='28/05/2017', eLearning=25, DataScience=16, MachineLearning=27, ArtificialIntelligence=15, DeepLearning=11)
# Pandas(Index=89, Week='4/06/2017', eLearning=25, DataScience=15, MachineLearning=29, ArtificialIntelligence=14, DeepLearning=11)
# Pandas(Index=90, Week='11/06/2017', eLearning=24, DataScience=16, MachineLearning=28, ArtificialIntelligence=15, DeepLearning=11)
# Pandas(Index=91, Week='18/06/2017', eLearning=20, DataScience=16, MachineLearning=28, ArtificialIntelligence=14, DeepLearning=11)
# Pandas(Index=92, Week='25/06/2017', eLearning=19, DataScience=16, MachineLearning=28, ArtificialIntelligence=15, DeepLearning=12)
# Pandas(Index=93, Week='2/07/2017', eLearning=21, DataScience=15, MachineLearning=27, ArtificialIntelligence=14, DeepLearning=11)
# Pandas(Index=94, Week='9/07/2017', eLearning=19, DataScience=16, MachineLearning=29, ArtificialIntelligence=15, DeepLearning=12)
# Pandas(Index=95, Week='16/07/2017', eLearning=18, DataScience=16, MachineLearning=28, ArtificialIntelligence=16, DeepLearning=13)
# Pandas(Index=96, Week='23/07/2017', eLearning=17, DataScience=17, MachineLearning=28, ArtificialIntelligence=18, DeepLearning=12)
# Pandas(Index=97, Week='30/07/2017', eLearning=16, DataScience=17, MachineLearning=29, ArtificialIntelligence=23, DeepLearning=12)
# Pandas(Index=98, Week='6/08/2017', eLearning=15, DataScience=17, MachineLearning=27, ArtificialIntelligence=18, DeepLearning=13)
# Pandas(Index=99, Week='13/08/2017', eLearning=15, DataScience=16, MachineLearning=28, ArtificialIntelligence=17, DeepLearning=13)
# Pandas(Index=100, Week='20/08/2017', eLearning=18, DataScience=18, MachineLearning=27, ArtificialIntelligence=17, DeepLearning=12)
# Pandas(Index=101, Week='27/08/2017', eLearning=19, DataScience=18, MachineLearning=28, ArtificialIntelligence=17, DeepLearning=12)
# Pandas(Index=102, Week='3/09/2017', eLearning=24, DataScience=19, MachineLearning=30, ArtificialIntelligence=23, DeepLearning=13)
# Pandas(Index=103, Week='10/09/2017', eLearning=27, DataScience=20, MachineLearning=31, ArtificialIntelligence=21, DeepLearning=13)
# Pandas(Index=104, Week='17/09/2017', eLearning=32, DataScience=20, MachineLearning=32, ArtificialIntelligence=20, DeepLearning=14)
# Pandas(Index=105, Week='24/09/2017', eLearning=34, DataScience=20, MachineLearning=31, ArtificialIntelligence=20, DeepLearning=13)
# Pandas(Index=106, Week='1/10/2017', eLearning=35, DataScience=19, MachineLearning=33, ArtificialIntelligence=20, DeepLearning=13)
# Pandas(Index=107, Week='8/10/2017', eLearning=35, DataScience=20, MachineLearning=34, ArtificialIntelligence=22, DeepLearning=13)
# Pandas(Index=108, Week='15/10/2017', eLearning=36, DataScience=20, MachineLearning=32, ArtificialIntelligence=21, DeepLearning=14)
# Pandas(Index=109, Week='22/10/2017', eLearning=34, DataScience=20, MachineLearning=35, ArtificialIntelligence=26, DeepLearning=13)
# Pandas(Index=110, Week='29/10/2017', eLearning=33, DataScience=21, MachineLearning=35, ArtificialIntelligence=24, DeepLearning=14)
# Pandas(Index=111, Week='5/11/2017', eLearning=33, DataScience=21, MachineLearning=37, ArtificialIntelligence=25, DeepLearning=14)
# Pandas(Index=112, Week='12/11/2017', eLearning=31, DataScience=20, MachineLearning=35, ArtificialIntelligence=24, DeepLearning=15)
# Pandas(Index=113, Week='19/11/2017', eLearning=29, DataScience=17, MachineLearning=33, ArtificialIntelligence=22, DeepLearning=14)
# Pandas(Index=114, Week='26/11/2017', eLearning=29, DataScience=19, MachineLearning=35, ArtificialIntelligence=25, DeepLearning=15)
# Pandas(Index=115, Week='3/12/2017', eLearning=30, DataScience=20, MachineLearning=36, ArtificialIntelligence=25, DeepLearning=15)
# Pandas(Index=116, Week='10/12/2017', eLearning=30, DataScience=20, MachineLearning=37, ArtificialIntelligence=23, DeepLearning=15)
# Pandas(Index=117, Week='17/12/2017', eLearning=24, DataScience=17, MachineLearning=32, ArtificialIntelligence=19, DeepLearning=14)
# Pandas(Index=118, Week='24/12/2017', eLearning=16, DataScience=14, MachineLearning=26, ArtificialIntelligence=17, DeepLearning=12)
# Pandas(Index=119, Week='31/12/2017', eLearning=18, DataScience=19, MachineLearning=30, ArtificialIntelligence=20, DeepLearning=13)
# Pandas(Index=120, Week='7/01/2018', eLearning=29, DataScience=22, MachineLearning=32, ArtificialIntelligence=21, DeepLearning=15)
# Pandas(Index=121, Week='14/01/2018', eLearning=27, DataScience=21, MachineLearning=34, ArtificialIntelligence=30, DeepLearning=14)
# Pandas(Index=122, Week='21/01/2018', eLearning=27, DataScience=21, MachineLearning=34, ArtificialIntelligence=29, DeepLearning=14)
# Pandas(Index=123, Week='28/01/2018', eLearning=26, DataScience=22, MachineLearning=36, ArtificialIntelligence=27, DeepLearning=16)
# Pandas(Index=124, Week='4/02/2018', eLearning=27, DataScience=20, MachineLearning=35, ArtificialIntelligence=24, DeepLearning=15)
# Pandas(Index=125, Week='11/02/2018', eLearning=27, DataScience=21, MachineLearning=34, ArtificialIntelligence=24, DeepLearning=13)
# Pandas(Index=126, Week='18/02/2018', eLearning=30, DataScience=21, MachineLearning=35, ArtificialIntelligence=24, DeepLearning=14)
# Pandas(Index=127, Week='25/02/2018', eLearning=33, DataScience=21, MachineLearning=36, ArtificialIntelligence=24, DeepLearning=14)
# Pandas(Index=128, Week='4/03/2018', eLearning=34, DataScience=22, MachineLearning=37, ArtificialIntelligence=23, DeepLearning=14)
# Pandas(Index=129, Week='11/03/2018', eLearning=34, DataScience=22, MachineLearning=36, ArtificialIntelligence=24, DeepLearning=14)
# Pandas(Index=130, Week='18/03/2018', eLearning=37, DataScience=23, MachineLearning=37, ArtificialIntelligence=23, DeepLearning=15)
# Pandas(Index=131, Week='25/03/2018', eLearning=36, DataScience=22, MachineLearning=36, ArtificialIntelligence=21, DeepLearning=14)
# Pandas(Index=132, Week='1/04/2018', eLearning=30, DataScience=22, MachineLearning=36, ArtificialIntelligence=21, DeepLearning=14)
# Pandas(Index=133, Week='8/04/2018', eLearning=33, DataScience=23, MachineLearning=36, ArtificialIntelligence=23, DeepLearning=15)
# Pandas(Index=134, Week='15/04/2018', eLearning=32, DataScience=21, MachineLearning=36, ArtificialIntelligence=24, DeepLearning=15)
# Pandas(Index=135, Week='22/04/2018', eLearning=33, DataScience=22, MachineLearning=37, ArtificialIntelligence=23, DeepLearning=15)
# Pandas(Index=136, Week='29/04/2018', eLearning=31, DataScience=22, MachineLearning=35, ArtificialIntelligence=22, DeepLearning=14)
# Pandas(Index=137, Week='6/05/2018', eLearning=31, DataScience=21, MachineLearning=37, ArtificialIntelligence=25, DeepLearning=15)
# Pandas(Index=138, Week='13/05/2018', eLearning=32, DataScience=22, MachineLearning=37, ArtificialIntelligence=23, DeepLearning=15)
# Pandas(Index=139, Week='20/05/2018', eLearning=30, DataScience=23, MachineLearning=37, ArtificialIntelligence=22, DeepLearning=14)
# Pandas(Index=140, Week='27/05/2018', eLearning=29, DataScience=22, MachineLearning=34, ArtificialIntelligence=21, DeepLearning=14)
# Pandas(Index=141, Week='3/06/2018', eLearning=30, DataScience=23, MachineLearning=37, ArtificialIntelligence=21, DeepLearning=14)
# Pandas(Index=142, Week='10/06/2018', eLearning=25, DataScience=21, MachineLearning=36, ArtificialIntelligence=19, DeepLearning=14)
# Pandas(Index=143, Week='17/06/2018', eLearning=24, DataScience=21, MachineLearning=36, ArtificialIntelligence=17, DeepLearning=14)
# Pandas(Index=144, Week='24/06/2018', eLearning=24, DataScience=21, MachineLearning=35, ArtificialIntelligence=19, DeepLearning=14)
# Pandas(Index=145, Week='1/07/2018', eLearning=24, DataScience=20, MachineLearning=34, ArtificialIntelligence=18, DeepLearning=13)
# Pandas(Index=146, Week='8/07/2018', eLearning=21, DataScience=23, MachineLearning=36, ArtificialIntelligence=19, DeepLearning=14)
# Pandas(Index=147, Week='15/07/2018', eLearning=21, DataScience=23, MachineLearning=36, ArtificialIntelligence=19, DeepLearning=14)
# Pandas(Index=148, Week='22/07/2018', eLearning=18, DataScience=22, MachineLearning=36, ArtificialIntelligence=20, DeepLearning=13)
# Pandas(Index=149, Week='29/07/2018', eLearning=17, DataScience=23, MachineLearning=36, ArtificialIntelligence=20, DeepLearning=14)
# Pandas(Index=150, Week='5/08/2018', eLearning=18, DataScience=23, MachineLearning=37, ArtificialIntelligence=20, DeepLearning=13)
# Pandas(Index=151, Week='12/08/2018', eLearning=17, DataScience=22, MachineLearning=36, ArtificialIntelligence=19, DeepLearning=12)
# Pandas(Index=152, Week='19/08/2018', eLearning=19, DataScience=24, MachineLearning=37, ArtificialIntelligence=18, DeepLearning=14)
# Pandas(Index=153, Week='26/08/2018', eLearning=23, DataScience=26, MachineLearning=38, ArtificialIntelligence=20, DeepLearning=14)
# Pandas(Index=154, Week='2/09/2018', eLearning=28, DataScience=27, MachineLearning=37, ArtificialIntelligence=21, DeepLearning=14)
# Pandas(Index=155, Week='9/09/2018', eLearning=34, DataScience=25, MachineLearning=38, ArtificialIntelligence=22, DeepLearning=14)
# Pandas(Index=156, Week='16/09/2018', eLearning=39, DataScience=25, MachineLearning=40, ArtificialIntelligence=22, DeepLearning=15)
# Pandas(Index=157, Week='23/09/2018', eLearning=38, DataScience=25, MachineLearning=39, ArtificialIntelligence=23, DeepLearning=15)
# Pandas(Index=158, Week='30/09/2018', eLearning=44, DataScience=26, MachineLearning=39, ArtificialIntelligence=21, DeepLearning=15)
# Pandas(Index=159, Week='7/10/2018', eLearning=43, DataScience=26, MachineLearning=39, ArtificialIntelligence=22, DeepLearning=15)
# Pandas(Index=160, Week='14/10/2018', eLearning=45, DataScience=26, MachineLearning=39, ArtificialIntelligence=23, DeepLearning=15)
# Pandas(Index=161, Week='21/10/2018', eLearning=42, DataScience=26, MachineLearning=40, ArtificialIntelligence=24, DeepLearning=15)
# Pandas(Index=162, Week='28/10/2018', eLearning=39, DataScience=24, MachineLearning=39, ArtificialIntelligence=23, DeepLearning=15)
# Pandas(Index=163, Week='4/11/2018', eLearning=37, DataScience=24, MachineLearning=36, ArtificialIntelligence=21, DeepLearning=15)
# Pandas(Index=164, Week='11/11/2018', eLearning=41, DataScience=26, MachineLearning=39, ArtificialIntelligence=25, DeepLearning=15)
# Pandas(Index=165, Week='18/11/2018', eLearning=35, DataScience=23, MachineLearning=37, ArtificialIntelligence=22, DeepLearning=14)
# Pandas(Index=166, Week='25/11/2018', eLearning=38, DataScience=26, MachineLearning=41, ArtificialIntelligence=24, DeepLearning=15)
# Pandas(Index=167, Week='2/12/2018', eLearning=38, DataScience=26, MachineLearning=42, ArtificialIntelligence=24, DeepLearning=16)
# Pandas(Index=168, Week='9/12/2018', eLearning=35, DataScience=26, MachineLearning=40, ArtificialIntelligence=22, DeepLearning=15)
# Pandas(Index=169, Week='16/12/2018', eLearning=30, DataScience=23, MachineLearning=37, ArtificialIntelligence=23, DeepLearning=13)
# Pandas(Index=170, Week='23/12/2018', eLearning=19, DataScience=19, MachineLearning=28, ArtificialIntelligence=17, DeepLearning=10)
# Pandas(Index=171, Week='30/12/2018', eLearning=20, DataScience=22, MachineLearning=31, ArtificialIntelligence=18, DeepLearning=11)
# Pandas(Index=172, Week='6/01/2019', eLearning=30, DataScience=29, MachineLearning=37, ArtificialIntelligence=22, DeepLearning=14)
# Pandas(Index=173, Week='13/01/2019', eLearning=31, DataScience=29, MachineLearning=37, ArtificialIntelligence=24, DeepLearning=15)
# Pandas(Index=174, Week='20/01/2019', eLearning=30, DataScience=28, MachineLearning=39, ArtificialIntelligence=22, DeepLearning=15)
# Pandas(Index=175, Week='27/01/2019', eLearning=29, DataScience=28, MachineLearning=40, ArtificialIntelligence=23, DeepLearning=15)
# Pandas(Index=176, Week='3/02/2019', eLearning=29, DataScience=29, MachineLearning=41, ArtificialIntelligence=23, DeepLearning=15)
# Pandas(Index=177, Week='10/02/2019', eLearning=32, DataScience=28, MachineLearning=40, ArtificialIntelligence=24, DeepLearning=15)
# Pandas(Index=178, Week='17/02/2019', eLearning=35, DataScience=30, MachineLearning=42, ArtificialIntelligence=25, DeepLearning=15)
# Pandas(Index=179, Week='24/02/2019', eLearning=38, DataScience=29, MachineLearning=41, ArtificialIntelligence=23, DeepLearning=15)
# Pandas(Index=180, Week='3/03/2019', eLearning=36, DataScience=28, MachineLearning=42, ArtificialIntelligence=23, DeepLearning=15)
# Pandas(Index=181, Week='10/03/2019', eLearning=39, DataScience=27, MachineLearning=40, ArtificialIntelligence=23, DeepLearning=15)
# Pandas(Index=182, Week='17/03/2019', eLearning=41, DataScience=28, MachineLearning=41, ArtificialIntelligence=23, DeepLearning=14)
# Pandas(Index=183, Week='24/03/2019', eLearning=38, DataScience=30, MachineLearning=41, ArtificialIntelligence=24, DeepLearning=16)
# Pandas(Index=184, Week='31/03/2019', eLearning=41, DataScience=29, MachineLearning=41, ArtificialIntelligence=23, DeepLearning=15)
# Pandas(Index=185, Week='7/04/2019', eLearning=38, DataScience=28, MachineLearning=41, ArtificialIntelligence=23, DeepLearning=16)
# Pandas(Index=186, Week='14/04/2019', eLearning=36, DataScience=27, MachineLearning=37, ArtificialIntelligence=21, DeepLearning=14)
# Pandas(Index=187, Week='21/04/2019', eLearning=36, DataScience=27, MachineLearning=39, ArtificialIntelligence=23, DeepLearning=15)
# Pandas(Index=188, Week='28/04/2019', eLearning=36, DataScience=27, MachineLearning=39, ArtificialIntelligence=24, DeepLearning=14)
# Pandas(Index=189, Week='5/05/2019', eLearning=36, DataScience=28, MachineLearning=41, ArtificialIntelligence=23, DeepLearning=14)
# Pandas(Index=190, Week='12/05/2019', eLearning=37, DataScience=29, MachineLearning=41, ArtificialIntelligence=24, DeepLearning=15)
# Pandas(Index=191, Week='19/05/2019', eLearning=35, DataScience=30, MachineLearning=39, ArtificialIntelligence=22, DeepLearning=15)
# Pandas(Index=192, Week='26/05/2019', eLearning=32, DataScience=29, MachineLearning=38, ArtificialIntelligence=21, DeepLearning=14)
# Pandas(Index=193, Week='2/06/2019', eLearning=27, DataScience=29, MachineLearning=40, ArtificialIntelligence=21, DeepLearning=14)
# Pandas(Index=194, Week='9/06/2019', eLearning=27, DataScience=30, MachineLearning=42, ArtificialIntelligence=22, DeepLearning=15)
# Pandas(Index=195, Week='16/06/2019', eLearning=32, DataScience=31, MachineLearning=41, ArtificialIntelligence=24, DeepLearning=15)
# Pandas(Index=196, Week='23/06/2019', eLearning=28, DataScience=30, MachineLearning=41, ArtificialIntelligence=22, DeepLearning=15)
# Pandas(Index=197, Week='30/06/2019', eLearning=32, DataScience=29, MachineLearning=40, ArtificialIntelligence=21, DeepLearning=14)
# Pandas(Index=198, Week='7/07/2019', eLearning=27, DataScience=31, MachineLearning=40, ArtificialIntelligence=22, DeepLearning=15)
# Pandas(Index=199, Week='14/07/2019', eLearning=23, DataScience=31, MachineLearning=41, ArtificialIntelligence=23, DeepLearning=15)
# Pandas(Index=200, Week='21/07/2019', eLearning=22, DataScience=31, MachineLearning=40, ArtificialIntelligence=22, DeepLearning=14)
# Pandas(Index=201, Week='28/07/2019', eLearning=20, DataScience=31, MachineLearning=39, ArtificialIntelligence=22, DeepLearning=13)
# Pandas(Index=202, Week='4/08/2019', eLearning=20, DataScience=30, MachineLearning=38, ArtificialIntelligence=21, DeepLearning=14)
# Pandas(Index=203, Week='11/08/2019', eLearning=19, DataScience=31, MachineLearning=39, ArtificialIntelligence=21, DeepLearning=14)
# Pandas(Index=204, Week='18/08/2019', eLearning=26, DataScience=35, MachineLearning=43, ArtificialIntelligence=22, DeepLearning=14)
# Pandas(Index=205, Week='25/08/2019', eLearning=27, DataScience=37, MachineLearning=43, ArtificialIntelligence=22, DeepLearning=14)
# Pandas(Index=206, Week='1/09/2019', eLearning=33, DataScience=34, MachineLearning=40, ArtificialIntelligence=22, DeepLearning=15)
# Pandas(Index=207, Week='8/09/2019', eLearning=42, DataScience=36, MachineLearning=44, ArtificialIntelligence=25, DeepLearning=15)
# Pandas(Index=208, Week='15/09/2019', eLearning=44, DataScience=37, MachineLearning=45, ArtificialIntelligence=25, DeepLearning=15)
# Pandas(Index=209, Week='22/09/2019', eLearning=45, DataScience=35, MachineLearning=46, ArtificialIntelligence=26, DeepLearning=15)
# Pandas(Index=210, Week='29/09/2019', eLearning=55, DataScience=34, MachineLearning=43, ArtificialIntelligence=23, DeepLearning=15)
# Pandas(Index=211, Week='6/10/2019', eLearning=53, DataScience=34, MachineLearning=43, ArtificialIntelligence=24, DeepLearning=15)
# Pandas(Index=212, Week='13/10/2019', eLearning=55, DataScience=34, MachineLearning=44, ArtificialIntelligence=24, DeepLearning=15)
# Pandas(Index=213, Week='20/10/2019', eLearning=52, DataScience=32, MachineLearning=42, ArtificialIntelligence=23, DeepLearning=14)
# Pandas(Index=214, Week='27/10/2019', eLearning=48, DataScience=31, MachineLearning=39, ArtificialIntelligence=22, DeepLearning=14)
# Pandas(Index=215, Week='3/11/2019', eLearning=49, DataScience=34, MachineLearning=44, ArtificialIntelligence=25, DeepLearning=14)
# Pandas(Index=216, Week='10/11/2019', eLearning=47, DataScience=33, MachineLearning=43, ArtificialIntelligence=24, DeepLearning=15)
# Pandas(Index=217, Week='17/11/2019', eLearning=46, DataScience=34, MachineLearning=45, ArtificialIntelligence=27, DeepLearning=15)
# Pandas(Index=218, Week='24/11/2019', eLearning=42, DataScience=30, MachineLearning=41, ArtificialIntelligence=24, DeepLearning=15)
# Pandas(Index=219, Week='1/12/2019', eLearning=43, DataScience=34, MachineLearning=43, ArtificialIntelligence=24, DeepLearning=14)
# Pandas(Index=220, Week='8/12/2019', eLearning=43, DataScience=32, MachineLearning=44, ArtificialIntelligence=25, DeepLearning=15)
# Pandas(Index=221, Week='15/12/2019', eLearning=38, DataScience=32, MachineLearning=42, ArtificialIntelligence=22, DeepLearning=15)
# Pandas(Index=222, Week='22/12/2019', eLearning=24, DataScience=26, MachineLearning=33, ArtificialIntelligence=17, DeepLearning=11)
# Pandas(Index=223, Week='29/12/2019', eLearning=23, DataScience=29, MachineLearning=33, ArtificialIntelligence=19, DeepLearning=12)
# Pandas(Index=224, Week='5/01/2020', eLearning=38, DataScience=35, MachineLearning=42, ArtificialIntelligence=25, DeepLearning=15)
# Pandas(Index=225, Week='12/01/2020', eLearning=34, DataScience=35, MachineLearning=42, ArtificialIntelligence=25, DeepLearning=15)
# Pandas(Index=226, Week='19/01/2020', eLearning=31, DataScience=36, MachineLearning=44, ArtificialIntelligence=24, DeepLearning=14)
# Pandas(Index=227, Week='26/01/2020', eLearning=30, DataScience=35, MachineLearning=43, ArtificialIntelligence=24, DeepLearning=14)
# Pandas(Index=228, Week='2/02/2020', eLearning=34, DataScience=36, MachineLearning=44, ArtificialIntelligence=24, DeepLearning=15)
# Pandas(Index=229, Week='9/02/2020', eLearning=37, DataScience=38, MachineLearning=44, ArtificialIntelligence=25, DeepLearning=16)
# Pandas(Index=230, Week='16/02/2020', eLearning=43, DataScience=38, MachineLearning=46, ArtificialIntelligence=26, DeepLearning=16)
# Pandas(Index=231, Week='23/02/2020', eLearning=42, DataScience=38, MachineLearning=46, ArtificialIntelligence=26, DeepLearning=16)
# Pandas(Index=232, Week='1/03/2020', eLearning=48, DataScience=37, MachineLearning=44, ArtificialIntelligence=25, DeepLearning=15)
# Pandas(Index=233, Week='8/03/2020', eLearning=57, DataScience=34, MachineLearning=39, ArtificialIntelligence=23, DeepLearning=14)
# Pandas(Index=234, Week='15/03/2020', eLearning=98, DataScience=29, MachineLearning=34, ArtificialIntelligence=19, DeepLearning=12)
# Pandas(Index=235, Week='22/03/2020', eLearning=100, DataScience=28, MachineLearning=33, ArtificialIntelligence=19, DeepLearning=12)
# Pandas(Index=236, Week='29/03/2020', eLearning=97, DataScience=30, MachineLearning=35, ArtificialIntelligence=19, DeepLearning=13)
# Pandas(Index=237, Week='5/04/2020', eLearning=100, DataScience=32, MachineLearning=38, ArtificialIntelligence=21, DeepLearning=13)
# Pandas(Index=238, Week='12/04/2020', eLearning=94, DataScience=34, MachineLearning=41, ArtificialIntelligence=22, DeepLearning=14)
# Pandas(Index=239, Week='19/04/2020', eLearning=98, DataScience=32, MachineLearning=41, ArtificialIntelligence=21, DeepLearning=15)
# Pandas(Index=240, Week='26/04/2020', eLearning=86, DataScience=33, MachineLearning=41, ArtificialIntelligence=20, DeepLearning=15)
# Pandas(Index=241, Week='3/05/2020', eLearning=86, DataScience=31, MachineLearning=41, ArtificialIntelligence=22, DeepLearning=15)
# Pandas(Index=242, Week='10/05/2020', eLearning=83, DataScience=33, MachineLearning=40, ArtificialIntelligence=22, DeepLearning=15)
# Pandas(Index=243, Week='17/05/2020', eLearning=66, DataScience=33, MachineLearning=40, ArtificialIntelligence=21, DeepLearning=15)
# Pandas(Index=244, Week='24/05/2020', eLearning=57, DataScience=32, MachineLearning=40, ArtificialIntelligence=20, DeepLearning=15)
# Pandas(Index=245, Week='31/05/2020', eLearning=65, DataScience=33, MachineLearning=41, ArtificialIntelligence=21, DeepLearning=14)
# Pandas(Index=246, Week='7/06/2020', eLearning=69, DataScience=33, MachineLearning=41, ArtificialIntelligence=20, DeepLearning=15)
# Pandas(Index=247, Week='14/06/2020', eLearning=61, DataScience=33, MachineLearning=40, ArtificialIntelligence=21, DeepLearning=15)
# Pandas(Index=248, Week='21/06/2020', eLearning=61, DataScience=34, MachineLearning=41, ArtificialIntelligence=20, DeepLearning=14)
# Pandas(Index=249, Week='28/06/2020', eLearning=59, DataScience=35, MachineLearning=38, ArtificialIntelligence=20, DeepLearning=14)
# Pandas(Index=250, Week='5/07/2020', eLearning=55, DataScience=35, MachineLearning=39, ArtificialIntelligence=19, DeepLearning=14)
# Pandas(Index=251, Week='12/07/2020', eLearning=58, DataScience=36, MachineLearning=40, ArtificialIntelligence=21, DeepLearning=15)
# Pandas(Index=252, Week='19/07/2020', eLearning=55, DataScience=36, MachineLearning=40, ArtificialIntelligence=21, DeepLearning=14)
# Pandas(Index=253, Week='26/07/2020', eLearning=43, DataScience=34, MachineLearning=39, ArtificialIntelligence=20, DeepLearning=14)
# Pandas(Index=254, Week='2/08/2020', eLearning=44, DataScience=34, MachineLearning=37, ArtificialIntelligence=20, DeepLearning=13)
# Pandas(Index=255, Week='9/08/2020', eLearning=44, DataScience=35, MachineLearning=38, ArtificialIntelligence=21, DeepLearning=13)
# Pandas(Index=256, Week='16/08/2020', eLearning=41, DataScience=36, MachineLearning=40, ArtificialIntelligence=22, DeepLearning=14)
# Pandas(Index=257, Week='23/08/2020', eLearning=49, DataScience=39, MachineLearning=40, ArtificialIntelligence=21, DeepLearning=14)
# Pandas(Index=258, Week='30/08/2020', eLearning=62, DataScience=37, MachineLearning=40, ArtificialIntelligence=21, DeepLearning=14)
# Pandas(Index=259, Week='6/09/2020', eLearning=74, DataScience=38, MachineLearning=42, ArtificialIntelligence=24, DeepLearning=14)
# Pandas(Index=260, Week='13/09/2020', eLearning=80, DataScience=39, MachineLearning=39, ArtificialIntelligence=21, DeepLearning=14)

# %% [markdown]
# 2. Sorting

# %%
sorted_data = trend_data.sort_index(ascending=False)
print(sorted_data)
# Out:
#            Week  eLearning  DataScience  MachineLearning  \
# 260  13/09/2020         80           39               39
# 259   6/09/2020         74           38               42
# 258  30/08/2020         62           37               40
# 257  23/08/2020         49           39               40
# 256  16/08/2020         41           36               40
# ..          ...        ...          ...              ...
# 4    18/10/2015         38            9               12
# 3    11/10/2015         37            9               12
# 2     4/10/2015         38           10               12
# 1    27/09/2015         35           10               11
# 0    20/09/2015         32            9               11
#
#      ArtificialIntelligence  DeepLearning
# 260                      21            14
# 259                      24            14
# 258                      21            14
# 257                      21            14
# 256                      22            14
# ..                      ...           ...
# 4                        10             4
# 3                        10             4
# 2                        11             4
# 1                        11             4
# 0                        11             4
#
# [261 rows x 6 columns]

# %% [markdown]
# 2b. Sorting by column

# %%
sorted_data=trend_data.sort_index(axis=1)
print(sorted_data)
# Out:
#      ArtificialIntelligence  DataScience  DeepLearning  MachineLearning  \
# 0                        11            9             4               11
# 1                        11           10             4               11
# 2                        11           10             4               12
# 3                        10            9             4               12
# 4                        10            9             4               12
# ..                      ...          ...           ...              ...
# 256                      22           36            14               40
# 257                      21           39            14               40
# 258                      21           37            14               40
# 259                      24           38            14               42
# 260                      21           39            14               39
#
#            Week  eLearning
# 0    20/09/2015         32
# 1    27/09/2015         35
# 2     4/10/2015         38
# 3    11/10/2015         37
# 4    18/10/2015         38
# ..          ...        ...
# 256  16/08/2020         41
# 257  23/08/2020         49
# 258  30/08/2020         62
# 259   6/09/2020         74
# 260  13/09/2020         80
#
# [261 rows x 6 columns]

# %% [markdown]
# 2c. Sort by values of a specific column

# %%
sorted_data = trend_data.sort_values(by='DataScience')
print(sorted_data)
# Out:
#            Week  eLearning  DataScience  MachineLearning  \
# 14   27/12/2015         17            7               10
# 13   20/12/2015         17            7               11
# 7     8/11/2015         35            8               14
# 9    22/11/2015         31            8               12
# 27   27/03/2016         29            9               14
# ..          ...        ...          ...              ...
# 230  16/02/2020         43           38               46
# 229   9/02/2020         37           38               44
# 259   6/09/2020         74           38               42
# 257  23/08/2020         49           39               40
# 260  13/09/2020         80           39               39
#
#      ArtificialIntelligence  DeepLearning
# 14                        9             3
# 13                        9             4
# 7                        12             5
# 9                        10             4
# 27                       12             6
# ..                      ...           ...
# 230                      26            16
# 229                      25            16
# 259                      24            14
# 257                      21            14
# 260                      21            14
#
# [261 rows x 6 columns]

# %%
sorted_data = trend_data.sort_values(by='DataScience', ascending=False)
print(sorted_data)
# Out:
#            Week  eLearning  DataScience  MachineLearning  \
# 260  13/09/2020         80           39               39
# 257  23/08/2020         49           39               40
# 230  16/02/2020         43           38               46
# 229   9/02/2020         37           38               44
# 231  23/02/2020         42           38               46
# ..          ...        ...          ...              ...
# 0    20/09/2015         32            9               11
# 9    22/11/2015         31            8               12
# 7     8/11/2015         35            8               14
# 13   20/12/2015         17            7               11
# 14   27/12/2015         17            7               10
#
#      ArtificialIntelligence  DeepLearning
# 260                      21            14
# 257                      21            14
# 230                      26            16
# 229                      25            16
# 231                      26            16
# ..                      ...           ...
# 0                        11             4
# 9                        10             4
# 7                        12             5
# 13                        9             4
# 14                        9             3
#
# [261 rows x 6 columns]

# %% [markdown]
# 2d. Sorting by a combination of columns

# %%
sorted_data = trend_data.sort_values(by=['DataScience','MachineLearning'])
print(sorted_data)
# Out:
#            Week  eLearning  DataScience  MachineLearning  \
# 14   27/12/2015         17            7               10
# 13   20/12/2015         17            7               11
# 9    22/11/2015         31            8               12
# 7     8/11/2015         35            8               14
# 0    20/09/2015         32            9               11
# ..          ...        ...          ...              ...
# 229   9/02/2020         37           38               44
# 230  16/02/2020         43           38               46
# 231  23/02/2020         42           38               46
# 260  13/09/2020         80           39               39
# 257  23/08/2020         49           39               40
#
#      ArtificialIntelligence  DeepLearning
# 14                        9             3
# 13                        9             4
# 9                        10             4
# 7                        12             5
# 0                        11             4
# ..                      ...           ...
# 229                      25            16
# 230                      26            16
# 231                      26            16
# 260                      21            14
# 257                      21            14
#
# [261 rows x 6 columns]

# %% [markdown]
# 2e. What kind of sorting algorithm to be used <br>
# The options avaiable are
# - mergesort
# - heapsort
# - quicksort
# It's better to go with the default one 'mergesort' as it is more stable

# %%
sorted_data = trend_data.sort_values(by='DataScience' ,kind='mergesort')
print(sorted_data)
# Out:
#            Week  eLearning  DataScience  MachineLearning  \
# 13   20/12/2015         17            7               11
# 14   27/12/2015         17            7               10
# 7     8/11/2015         35            8               14
# 9    22/11/2015         31            8               12
# 0    20/09/2015         32            9               11
# ..          ...        ...          ...              ...
# 230  16/02/2020         43           38               46
# 231  23/02/2020         42           38               46
# 259   6/09/2020         74           38               42
# 257  23/08/2020         49           39               40
# 260  13/09/2020         80           39               39
#
#      ArtificialIntelligence  DeepLearning
# 13                        9             4
# 14                        9             3
# 7                        12             5
# 9                        10             4
# 0                        11             4
# ..                      ...           ...
# 230                      26            16
# 231                      26            16
# 259                      24            14
# 257                      21            14
# 260                      21            14
#
# [261 rows x 6 columns]

# %% [markdown]
# #### To Try
# - Sort based on eLearning and Deep Learning
# - Filter the last 50 weeks and sort based on the Data Scice trend score
# - Print on the rows(Weeks) where the trend score for atleast one item is over 40
# - Try the above worked example on a different dataset
