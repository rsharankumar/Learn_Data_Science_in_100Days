# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
train = pd.read_csv("../Data/Titanic/train.csv")
test = pd.read_csv("../Data/Titanic/test.csv")

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# #### EDA - Exploratory Data Analysis

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Missing Values
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
train[["Sex", "Survived"]].groupby(["Sex"], as_index = False).mean()
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %%
sns.catplot(x="Sex", y ="Survived", data=train, kind="bar", height=3)
plt.show()

# %%
sns.FacetGrid(train, col="Survived").map(sns.histplot, "Age", bins=25)
plt.show()

# %%
sns.scatterplot(x = train.PassengerId, y = train['Age'], hue = train['Survived'])
plt.show()

# %%
sns.FacetGrid(train, col="Survived").map(sns.histplot, "Fare", bins=25)
plt.show()

# %%
sns.scatterplot(x = train.Fare, y = train['Age'], hue = train['Survived'])
plt.show()

# %%
sns.catplot(x="Pclass", y ="Survived", data=train, kind="bar", height=3)
plt.show()

# %%
sns.countplot(x='Survived',hue='Pclass',data=train)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.catplot(x="SibSp", y ="Survived", data=train, kind="bar", height=3)
plt.show()

# %%
train[["Parch", "Survived"]].groupby(["Parch"], as_index = False).agg(['count','mean'])
# Out:
#       Survived
#          count      mean
# Parch
# 0          678  0.343658
# 1          118  0.550847
# 2           80  0.500000
# 3            5  0.600000
# 4            4  0.000000
# 5            5  0.200000
# 6            1  0.000000

# %%
train[["Embarked", "Survived"]].groupby(["Embarked"], as_index = False).agg(['count','mean'])
# Out:
#          Survived
#             count      mean
# Embarked
# C             168  0.553571
# Q              77  0.389610
# S             644  0.336957

# %%
sns.catplot(x="Embarked", y ="Survived", data=train, kind="bar", height=3)
plt.show()

# %%
pd.crosstab([train.Sex,train.Survived],train.Pclass,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_7f458a86_42cd_11eb_83b2_acde48001122row0_col0,#T_7f458a86_42cd_11eb_83b2_acde48001122row0_col1,#T_7f458a86_42cd_11eb_83b2_acde48001122row0_col3,#T_7f458a86_42cd_11eb_83b2_acde48001122row3_col2{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_7f458a86_42cd_11eb_83b2_acde48001122row0_col2,#T_7f458a86_42cd_11eb_83b2_acde48001122row1_col2{
#             background-color:  #f1f866;
#             color:  #000000;
#         }#T_7f458a86_42cd_11eb_83b2_acde48001122row1_col0{
#             background-color:  #96cb66;
#             color:  #000000;
#         }#T_7f458a86_42cd_11eb_83b2_acde48001122row1_col1{
#             background-color:  #a3d166;
#             color:  #000000;
#         }#T_7f458a86_42cd_11eb_83b2_acde48001122row1_col3{
#             background-color:  #cfe766;
#             color:  #000000;
#         }#T_7f458a86_42cd_11eb_83b2_acde48001122row2_col0{
#             background-color:  #a7d366;
#             color:  #000000;
#         }#T_7f458a86_42cd_11eb_83b2_acde48001122row2_col1,#T_7f458a86_42cd_11eb_83b2_acde48001122row2_col3{
#             background-color:  #85c266;
#             color:  #000000;
#         }#T_7f458a86_42cd_11eb_83b2_acde48001122row2_col2{
#             background-color:  #6eb666;
#             color:  #000000;
#         }#T_7f458a86_42cd_11eb_83b2_acde48001122row3_col0{
#             background-color:  #cde666;
#             color:  #000000;
#         }#T_7f458a86_42cd_11eb_83b2_acde48001122row3_col1{
#             background-color:  #f0f866;
#             color:  #000000;
#         }#T_7f458a86_42cd_11eb_83b2_acde48001122row3_col3{
#             background-color:  #f7fb66;
#             color:  #000000;
#         }#T_7f458a86_42cd_11eb_83b2_acde48001122row4_col0,#T_7f458a86_42cd_11eb_83b2_acde48001122row4_col1,#T_7f458a86_42cd_11eb_83b2_acde48001122row4_col2,#T_7f458a86_42cd_11eb_83b2_acde48001122row4_col3{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_7f458a86_42cd_11eb_83b2_acde48001122" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Pclass</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>        <th class="col_heading level0 col3" >All</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="index_name level1" >Survived</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7f458a86_42cd_11eb_83b2_acde48001122level0_row0" class="row_heading level0 row0" rowspan=2>female</th>
#                         <th id="T_7f458a86_42cd_11eb_83b2_acde48001122level1_row0" class="row_heading level1 row0" >0</th>
#                         <td id="T_7f458a86_42cd_11eb_83b2_acde48001122row0_col0" class="data row0 col0" >3</td>
#                         <td id="T_7f458a86_42cd_11eb_83b2_acde48001122row0_col1" class="data row0 col1" >6</td>
#                         <td id="T_7f458a86_42cd_11eb_83b2_acde48001122row0_col2" class="data row0 col2" >72</td>
#                         <td id="T_7f458a86_42cd_11eb_83b2_acde48001122row0_col3" class="data row0 col3" >81</td>
#             </tr>
#             <tr>
#                                 <th id="T_7f458a86_42cd_11eb_83b2_acde48001122level1_row1" class="row_heading level1 row1" >1</th>
#                         <td id="T_7f458a86_42cd_11eb_83b2_acde48001122row1_col0" class="data row1 col0" >91</td>
#                         <td id="T_7f458a86_42cd_11eb_83b2_acde48001122row1_col1" class="data row1 col1" >70</td>
#                         <td id="T_7f458a86_42cd_11eb_83b2_acde48001122row1_col2" class="data row1 col2" >72</td>
#                         <td id="T_7f458a86_42cd_11eb_83b2_acde48001122row1_col3" class="data row1 col3" >233</td>
#             </tr>
#             <tr>
#                         <th id="T_7f458a86_42cd_11eb_83b2_acde48001122level0_row2" class="row_heading level0 row2" rowspan=2>male</th>
#                         <th id="T_7f458a86_42cd_11eb_83b2_acde48001122level1_row2" class="row_heading level1 row2" >0</th>
#                         <td id="T_7f458a86_42cd_11eb_83b2_acde48001122row2_col0" class="data row2 col0" >77</td>
#                         <td id="T_7f458a86_42cd_11eb_83b2_acde48001122row2_col1" class="data row2 col1" >91</td>
#                         <td id="T_7f458a86_42cd_11eb_83b2_acde48001122row2_col2" class="data row2 col2" >300</td>
#                         <td id="T_7f458a86_42cd_11eb_83b2_acde48001122row2_col3" class="data row2 col3" >468</td>
#             </tr>
#             <tr>
#                                 <th id="T_7f458a86_42cd_11eb_83b2_acde48001122level1_row3" class="row_heading level1 row3" >1</th>
#                         <td id="T_7f458a86_42cd_11eb_83b2_acde48001122row3_col0" class="data row3 col0" >45</td>
#                         <td id="T_7f458a86_42cd_11eb_83b2_acde48001122row3_col1" class="data row3 col1" >17</td>
#                         <td id="T_7f458a86_42cd_11eb_83b2_acde48001122row3_col2" class="data row3 col2" >47</td>
#                         <td id="T_7f458a86_42cd_11eb_83b2_acde48001122row3_col3" class="data row3 col3" >109</td>
#             </tr>
#             <tr>
#                         <th id="T_7f458a86_42cd_11eb_83b2_acde48001122level0_row4" class="row_heading level0 row4" >All</th>
#                         <th id="T_7f458a86_42cd_11eb_83b2_acde48001122level1_row4" class="row_heading level1 row4" ></th>
#                         <td id="T_7f458a86_42cd_11eb_83b2_acde48001122row4_col0" class="data row4 col0" >216</td>
#                         <td id="T_7f458a86_42cd_11eb_83b2_acde48001122row4_col1" class="data row4 col1" >184</td>
#                         <td id="T_7f458a86_42cd_11eb_83b2_acde48001122row4_col2" class="data row4 col2" >491</td>
#                         <td id="T_7f458a86_42cd_11eb_83b2_acde48001122row4_col3" class="data row4 col3" >891</td>
#             </tr>
#     </tbody></table>

# %%
pd.crosstab([train.Embarked,train.Pclass],[train.Sex,train.Survived],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_800f08e8_42cd_11eb_83b2_acde48001122row0_col0,#T_800f08e8_42cd_11eb_83b2_acde48001122row1_col2{
#             background-color:  #fcfe66;
#             color:  #000000;
#         }#T_800f08e8_42cd_11eb_83b2_acde48001122row0_col1{
#             background-color:  #d2e866;
#             color:  #000000;
#         }#T_800f08e8_42cd_11eb_83b2_acde48001122row0_col2{
#             background-color:  #f2f866;
#             color:  #000000;
#         }#T_800f08e8_42cd_11eb_83b2_acde48001122row0_col3{
#             background-color:  #d8ec66;
#             color:  #000000;
#         }#T_800f08e8_42cd_11eb_83b2_acde48001122row0_col4,#T_800f08e8_42cd_11eb_83b2_acde48001122row2_col3{
#             background-color:  #e8f466;
#             color:  #000000;
#         }#T_800f08e8_42cd_11eb_83b2_acde48001122row1_col0,#T_800f08e8_42cd_11eb_83b2_acde48001122row3_col0,#T_800f08e8_42cd_11eb_83b2_acde48001122row3_col1,#T_800f08e8_42cd_11eb_83b2_acde48001122row3_col2,#T_800f08e8_42cd_11eb_83b2_acde48001122row3_col3,#T_800f08e8_42cd_11eb_83b2_acde48001122row3_col4,#T_800f08e8_42cd_11eb_83b2_acde48001122row4_col0,#T_800f08e8_42cd_11eb_83b2_acde48001122row4_col2,#T_800f08e8_42cd_11eb_83b2_acde48001122row4_col3,#T_800f08e8_42cd_11eb_83b2_acde48001122row4_col4{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_800f08e8_42cd_11eb_83b2_acde48001122row1_col1,#T_800f08e8_42cd_11eb_83b2_acde48001122row6_col0{
#             background-color:  #f9fc66;
#             color:  #000000;
#         }#T_800f08e8_42cd_11eb_83b2_acde48001122row1_col3,#T_800f08e8_42cd_11eb_83b2_acde48001122row1_col4{
#             background-color:  #fbfd66;
#             color:  #000000;
#         }#T_800f08e8_42cd_11eb_83b2_acde48001122row2_col0,#T_800f08e8_42cd_11eb_83b2_acde48001122row5_col1{
#             background-color:  #e6f266;
#             color:  #000000;
#         }#T_800f08e8_42cd_11eb_83b2_acde48001122row2_col1{
#             background-color:  #f0f866;
#             color:  #000000;
#         }#T_800f08e8_42cd_11eb_83b2_acde48001122row2_col2{
#             background-color:  #eef666;
#             color:  #000000;
#         }#T_800f08e8_42cd_11eb_83b2_acde48001122row2_col4,#T_800f08e8_42cd_11eb_83b2_acde48001122row7_col0{
#             background-color:  #edf666;
#             color:  #000000;
#         }#T_800f08e8_42cd_11eb_83b2_acde48001122row4_col1{
#             background-color:  #fefe66;
#             color:  #000000;
#         }#T_800f08e8_42cd_11eb_83b2_acde48001122row5_col0{
#             background-color:  #e3f166;
#             color:  #000000;
#         }#T_800f08e8_42cd_11eb_83b2_acde48001122row5_col2{
#             background-color:  #ecf666;
#             color:  #000000;
#         }#T_800f08e8_42cd_11eb_83b2_acde48001122row5_col3{
#             background-color:  #f8fc66;
#             color:  #000000;
#         }#T_800f08e8_42cd_11eb_83b2_acde48001122row5_col4{
#             background-color:  #ebf566;
#             color:  #000000;
#         }#T_800f08e8_42cd_11eb_83b2_acde48001122row6_col1{
#             background-color:  #cde666;
#             color:  #000000;
#         }#T_800f08e8_42cd_11eb_83b2_acde48001122row6_col2{
#             background-color:  #e4f266;
#             color:  #000000;
#         }#T_800f08e8_42cd_11eb_83b2_acde48001122row6_col3{
#             background-color:  #bede66;
#             color:  #000000;
#         }#T_800f08e8_42cd_11eb_83b2_acde48001122row6_col4{
#             background-color:  #dbed66;
#             color:  #000000;
#         }#T_800f08e8_42cd_11eb_83b2_acde48001122row7_col1{
#             background-color:  #bdde66;
#             color:  #000000;
#         }#T_800f08e8_42cd_11eb_83b2_acde48001122row7_col2{
#             background-color:  #d3e966;
#             color:  #000000;
#         }#T_800f08e8_42cd_11eb_83b2_acde48001122row7_col3,#T_800f08e8_42cd_11eb_83b2_acde48001122row8_col1{
#             background-color:  #dcee66;
#             color:  #000000;
#         }#T_800f08e8_42cd_11eb_83b2_acde48001122row7_col4{
#             background-color:  #d1e866;
#             color:  #000000;
#         }#T_800f08e8_42cd_11eb_83b2_acde48001122row8_col0{
#             background-color:  #52a866;
#             color:  #000000;
#         }#T_800f08e8_42cd_11eb_83b2_acde48001122row8_col2{
#             background-color:  #81c066;
#             color:  #000000;
#         }#T_800f08e8_42cd_11eb_83b2_acde48001122row8_col3{
#             background-color:  #b0d866;
#             color:  #000000;
#         }#T_800f08e8_42cd_11eb_83b2_acde48001122row8_col4{
#             background-color:  #9acc66;
#             color:  #000000;
#         }#T_800f08e8_42cd_11eb_83b2_acde48001122row9_col0,#T_800f08e8_42cd_11eb_83b2_acde48001122row9_col1,#T_800f08e8_42cd_11eb_83b2_acde48001122row9_col2,#T_800f08e8_42cd_11eb_83b2_acde48001122row9_col3,#T_800f08e8_42cd_11eb_83b2_acde48001122row9_col4{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_800f08e8_42cd_11eb_83b2_acde48001122" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Sex</th>        <th class="col_heading level0 col0" colspan=2>female</th>        <th class="col_heading level0 col2" colspan=2>male</th>        <th class="col_heading level0 col4" >All</th>    </tr>    <tr>        <th class="blank" ></th>        <th class="index_name level1" >Survived</th>        <th class="col_heading level1 col0" >0</th>        <th class="col_heading level1 col1" >1</th>        <th class="col_heading level1 col2" >0</th>        <th class="col_heading level1 col3" >1</th>        <th class="col_heading level1 col4" ></th>    </tr>    <tr>        <th class="index_name level0" >Embarked</th>        <th class="index_name level1" >Pclass</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_800f08e8_42cd_11eb_83b2_acde48001122level0_row0" class="row_heading level0 row0" rowspan=3>C</th>
#                         <th id="T_800f08e8_42cd_11eb_83b2_acde48001122level1_row0" class="row_heading level1 row0" >1</th>
#                         <td id="T_800f08e8_42cd_11eb_83b2_acde48001122row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_800f08e8_42cd_11eb_83b2_acde48001122row0_col1" class="data row0 col1" >42</td>
#                         <td id="T_800f08e8_42cd_11eb_83b2_acde48001122row0_col2" class="data row0 col2" >25</td>
#                         <td id="T_800f08e8_42cd_11eb_83b2_acde48001122row0_col3" class="data row0 col3" >17</td>
#                         <td id="T_800f08e8_42cd_11eb_83b2_acde48001122row0_col4" class="data row0 col4" >85</td>
#             </tr>
#             <tr>
#                                 <th id="T_800f08e8_42cd_11eb_83b2_acde48001122level1_row1" class="row_heading level1 row1" >2</th>
#                         <td id="T_800f08e8_42cd_11eb_83b2_acde48001122row1_col0" class="data row1 col0" >0</td>
#                         <td id="T_800f08e8_42cd_11eb_83b2_acde48001122row1_col1" class="data row1 col1" >7</td>
#                         <td id="T_800f08e8_42cd_11eb_83b2_acde48001122row1_col2" class="data row1 col2" >8</td>
#                         <td id="T_800f08e8_42cd_11eb_83b2_acde48001122row1_col3" class="data row1 col3" >2</td>
#                         <td id="T_800f08e8_42cd_11eb_83b2_acde48001122row1_col4" class="data row1 col4" >17</td>
#             </tr>
#             <tr>
#                                 <th id="T_800f08e8_42cd_11eb_83b2_acde48001122level1_row2" class="row_heading level1 row2" >3</th>
#                         <td id="T_800f08e8_42cd_11eb_83b2_acde48001122row2_col0" class="data row2 col0" >8</td>
#                         <td id="T_800f08e8_42cd_11eb_83b2_acde48001122row2_col1" class="data row2 col1" >15</td>
#                         <td id="T_800f08e8_42cd_11eb_83b2_acde48001122row2_col2" class="data row2 col2" >33</td>
#                         <td id="T_800f08e8_42cd_11eb_83b2_acde48001122row2_col3" class="d

# %% [markdown]
# #### Transformation to Features

# %%
genders = {"male": 0, "female": 1}
data = [train, test]

for dataset in data:
    dataset['Sex'] = dataset['Sex'].map(genders)

# %%
train.Sex.unique()
# Out:
# array([0, 1])

# %%
embark = {"S": 0, "C": 1, "Q": 2}
data = [train, test]

for dataset in data:
    dataset['Embarked'] = dataset['Embarked'].map(embark)

# %%
test.Embarked.unique()
# Out:
# array([2, 0, 1])

# %%
data = [train, test]

for dataset in data:
    dataset['Fare'] = dataset['Fare'].fillna(0)
    dataset['Fare'] = dataset['Fare'].astype(int)

# %%
train[train["Age"].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#      Sex  Age  SibSp  Parch      Ticket  Fare Cabin  Embarked
# 5      0  NaN      0      0      330877     8   NaN       2.0
# 17     0  NaN      0      0      244373    13   NaN       0.0
# 19     1  NaN      0      0        2649     7   NaN       1.0
# 26     0  NaN      0      0        2631     7   NaN       1.0
# 28     1  NaN      0      0      330959     7   NaN       2.0
# ..   ...  ...    ...    ...         ...   ...   ...       ...
# 859    0  NaN      0      0        2629     7   NaN       1.0
# 863    1  NaN      8      2    CA. 2343    69   NaN       0.0
# 868    0  NaN      0      0      345777     9   NaN       0.0
# 878    0  NaN      0      0      349217     7   NaN       0.0
# 888    1  NaN      1      2  W./C. 6607    23   NaN       0.0
#
# [177 rows x 12 columns]

# %%
data_train_test = pd.concat([train.assign(ind="train"), test.assign(ind="test")], ignore_index=True)

# %%
age_nan_pos = data_train_test[data_train_test["Age"].isnull()].index
for i in age_nan_pos:
    mean_age = data_train_test["Age"][((data_train_test["Title"] == data_train_test.iloc[i]["Title"]))].mean()
    data_train_test["Age"].iloc[i] = mean_age
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/DS100/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Title'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-8d578bbbb6c5> in <module>
#       1 age_nan_pos = data_train_test[data_train_test["Age"].isnull()].index
#       2 for i in age_nan_pos:
# ----> 3     mean_age = data_train_test["Age"][((data_train_test["Title"] == data_train_test.iloc[i]["Title"]))].mean()
#       4     data_train_test["Age"].iloc[i] = mean_age
#
# ~/opt/anaconda3/envs/DS100/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# ~/opt/anaconda3/envs/DS100/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'Title'

# %%
test, train = data_train_test[data_train_test["ind"].eq("test")], data_train_test[data_train_test["ind"].eq("train")]

# %%
train[train["Age"].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6       0.0       3                          Moran, Mr. James
# 17            18       1.0       2              Williams, Mr. Charles Eugene
# 19            20       1.0       3                   Masselmani, Mrs. Fatima
# 26            27       0.0       3                   Emir, Mr. Farred Chehab
# 28            29       1.0       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860       0.0       3                          Razi, Mr. Raihed
# 863          864       0.0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869       0.0       3               van Melkebeke, Mr. Philemon
# 878          879       0.0       3                        Laleff, Mr. Kristo
# 888          889       0.0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#      Sex  Age  SibSp  Parch      Ticket  Fare Cabin  Embarked    ind
# 5      0  NaN      0      0      330877     8   NaN       2.0  train
# 17     0  NaN      0      0      244373    13   NaN       0.0  train
# 19     1  NaN      0      0        2649     7   NaN       1.0  train
# 26     0  NaN      0      0        2631     7   NaN       1.0  train
# 28     1  NaN      0      0      330959     7   NaN       2.0  train
# ..   ...  ...    ...    ...         ...   ...   ...       ...    ...
# 859    0  NaN      0      0        2629     7   NaN       1.0  train
# 863    1  NaN      8      2    CA. 2343    69   NaN       0.0  train
# 868    0  NaN      0      0      345777     9   NaN       0.0  train
# 878    0  NaN      0      0      349217     7   NaN       0.0  train
# 888    1  NaN      1      2  W./C. 6607    23   NaN       0.0  train
#
# [177 rows x 13 columns]

# %%
data = [train, test]
for dataset in data:
    dataset['Age'] = dataset['Age'].astype(int)
    dataset.loc[ dataset['Age'] <= 15, 'Age'] = 0
    dataset.loc[(dataset['Age'] > 15) & (dataset['Age'] <= 30), 'Age'] = 1
    dataset.loc[(dataset['Age'] > 30) & (dataset['Age'] <= 45), 'Age'] = 2
    dataset.loc[(dataset['Age'] > 45) & (dataset['Age'] <= 60), 'Age'] = 3
    dataset.loc[ dataset['Age'] > 60, 'Age'] = 4
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-8d76b63351f3> in <module>
#       1 data = [train, test]
#       2 for dataset in data:
# ----> 3     dataset['Age'] = dataset['Age'].astype(int)
#       4     dataset.loc[ dataset['Age'] <= 15, 'Age'] = 0
#       5     dataset.loc[(dataset['Age'] > 15) & (dataset['Age'] <= 30), 'Age'] = 1
#
# ~/opt/anaconda3/envs/DS100/lib/python3.8/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5544         else:
#    5545             # else, only a single dtype is given
# -> 5546             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5547             return self._constructor(new_data).__finalize__(self, method="astype")
#    5548
#
# ~/opt/anaconda3/envs/DS100/lib/python3.8/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     593         self, dtype, copy: bool = False, errors: str = "raise"
#     594     ) -> "BlockManager":
# --> 595         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     596
#     597     def convert(
#
# ~/opt/anaconda3/envs/DS100/lib/python3.8/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, **kwargs)
#     404                 applied = b.apply(f, **kwargs)
#     405             else:
# --> 406                 applied = getattr(b, f)(**kwargs)
#     407             result_blocks = _extend_blocks(applied, result_blocks)
#     408
#
# ~/opt/anaconda3/envs/DS100/lib/python3.8/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     593             vals1d = values.ravel()
#     594             try:
# --> 595                 values = astype_nansafe(vals1d, dtype, copy=True)
#     596             except (ValueError, TypeError):
#     597                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~/opt/anaconda3/envs/DS100/lib/python3.8/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     966
#     967         if not np.isfinite(arr).all():
# --> 968             raise ValueError("Cannot convert non-finite values (NA or inf) to integer")
#     969
#     970     elif is_object_dtype(arr):
#
# ValueError: Cannot convert non-finite values (NA or inf) to integer

# %%
train.Age.unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
train.drop(labels=["Ticket","Cabin", "ind"], axis=1, inplace = True)
test.drop(labels=["Ticket","Cabin", "ind"], axis=1, inplace = True)
# Out:
# /Users/rsharankumar/opt/anaconda3/envs/DS100/lib/python3.8/site-packages/pandas/core/frame.py:4167: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#    Fare  Embarked
# 0     7       0.0
# 1    71       1.0
# 2     7       0.0
# 3    53       0.0
# 4     8       0.0

# %%
sns.heatmap(train.corr(),annot=True,cmap='RdYlGn',linewidths=0.2,annot_kws={'size':14})
fig=plt.gcf()
fig.set_size_inches(14,10)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %% [markdown]
# #### Creating new features

# %%
data = [train, test]
for dataset in data:
    dataset['FamilySize'] = dataset['SibSp'] + dataset['Parch'] + 1
# Out:
# <ipython-input-39-7063c218b003>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['FamilySize'] = dataset['SibSp'] + dataset['Parch'] + 1

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#    Fare  Embarked  FamilySize
# 0     7       0.0           2
# 1    71       1.0           2
# 2     7       0.0           1
# 3    53       0.0           2
# 4     8       0.0           1

# %%
train[["FamilySize", "Survived"]].groupby(["FamilySize"], as_index = False).agg(['count','sum', 'mean'])
# Out:
#            Survived
#               count    sum      mean
# FamilySize
# 1               537  163.0  0.303538
# 2               161   89.0  0.552795
# 3               102   59.0  0.578431
# 4                29   21.0  0.724138
# 5                15    3.0  0.200000
# 6                22    3.0  0.136364
# 7                12    4.0  0.333333
# 8                 6    0.0  0.000000
# 11                7    0.0  0.000000

# %%
data = [train, test]
for dataset in data:
    dataset['Age*Fare'] = dataset.Age * dataset.Fare
# Out:
# <ipython-input-42-f09d40a6b7c4>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['Age*Fare'] = dataset.Age * dataset.Fare

# %%
train.loc[:, ['Age*Fare', 'Age', 'Fare']].head(10)
# Out:
#    Age*Fare   Age  Fare
# 0     154.0  22.0     7
# 1    2698.0  38.0    71
# 2     182.0  26.0     7
# 3    1855.0  35.0    53
# 4     280.0  35.0     8
# 5       NaN   NaN     8
# 6    2754.0  54.0    51
# 7      42.0   2.0    21
# 8     297.0  27.0    11
# 9     420.0  14.0    30

# %%
data = [train, test]
titles = {"Mr": 1, "Miss": 2, "Mrs": 3, "Master": 4, "Other": 5}

for dataset in data:
    dataset['Title'] = dataset.Name.str.extract(' ([A-Za-z]+)\.', expand=False)
    dataset['Title'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],inplace=True)
    # convert titles into numbers
    dataset['Title'] = dataset['Title'].map(titles)
    # filling NaN with 0, to get safe
    dataset['Title'] = dataset['Title'].fillna(0)

train = train.drop(['Name'], axis=1)  
test = test.drop(['Name'], axis=1)
# Out:
# <ipython-input-44-fef7d8bbe334>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['Title'] = dataset.Name.str.extract(' ([A-Za-z]+)\.', expand=False)
# /Users/rsharankumar/opt/anaconda3/envs/DS100/lib/python3.8/site-packages/pandas/core/series.py:4575: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(
# <ipython-input-44-fef7d8bbe334>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['Title'] = dataset['Title'].map(titles)
# <ipython-input-44-fef7d8bbe334>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['Title'] = dataset['Title'].fillna(0)

# %%
data = [train, test]
for dataset in data:
    dataset['Fare'] = pd.qcut(dataset['Fare'], 13, labels=np.arange(13) + 1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-a64108234aef> in <module>
#       1 data = [train, test]
#       2 for dataset in data:
# ----> 3     dataset['Fare'] = pd.qcut(dataset['Fare'], 13, labels=np.arange(13) + 1)
#
# ~/opt/anaconda3/envs/DS100/lib/python3.8/site-packages/pandas/core/reshape/tile.py in qcut(x, q, labels, retbins, precision, duplicates)
#     358         quantiles = q
#     359     bins = algos.quantile(x, quantiles)
# --> 360     fac, bins = _bins_to_cuts(
#     361         x,
#     362         bins,
#
# ~/opt/anaconda3/envs/DS100/lib/python3.8/site-packages/pandas/core/reshape/tile.py in _bins_to_cuts(x, bins, right, labels, precision, include_lowest, dtype, duplicates, ordered)
#     399     if len(unique_bins) < len(bins) and len(bins) != 2:
#     400         if duplicates == "raise":
# --> 401             raise ValueError(
#     402                 f"Bin edges must be unique: {repr(bins)}.\n"
#     403                 f"You can drop duplicate edges by setting the 'duplicates' kwarg"
#
# ValueError: Bin edges must be unique: array([  0.,   7.,   7.,   7.,   8.,  10.,  13.,  15.,  24.,  26.,  33.,
#         55.,  83., 512.]).
# You can drop duplicate edges by setting the 'duplicates' kwarg

# %%
train.Fare.unique()
# Out:
# array([  7,  71,  53,   8,  51,  21,  11,  30,  16,  26,  31,  29,  13,
#         18,  35, 263,  27, 146,  10,  82,  52,   9,  41,  15,  17,  39,
#         76,  61,  46,  80,  83,  73,  14,  56,  12,  47,  34,  20,  63,
#         23,  77,  24, 247,  22,   6,  79,  36,  66,  69,  55,  25,  33,
#         28,   0,  50, 113,  90,  86, 512, 153, 135,  19,  78,  91, 151,
#        110, 108, 262, 164, 134,  57, 133,  75, 211,   4, 227, 120,  32,
#         81,  89,  38,  49,  59,  93, 221, 106,  40,  42,  65,  37,   5])
